# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import AerSimulator

# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService(channel="ibm_quantum")
# backend = service.least_busy(operational=True, simulator=False)
backend = AerSimulator()
backend
# Out:
# AerSimulator('aer_simulator')

# %%
# hamiltonian = SparsePauliOp.from_list(
#     [("YZ", 0.3980), ("IZ", -0.3980), ("ZI", -0.0113), ("XX", 0.1810)]
# )
# hamiltonian = SparsePauliOp.from_list(
#     [("YZ", 1), ("ZI", 1), ("ZZ", 1), ("XX", 1)]
# )
# hamiltonian = SparsePauliOp.from_list(
#         [
#         ('IIII', -0.09706627+0.j), ('ZIII',  0.17141283+0.j), ('IZII',  0.17141283+0.j),
#         ('IIZI', -0.22343154+0.j), ('IIIZ', -0.22343154+0.j), ('ZZII',  0.16868898+0.j),
#         ('ZIZI',  0.12062523+0.j), ('ZIIZ',  0.16592785+0.j), ('IZZI',  0.16592785+0.j),
#         ('IZIZ',  0.12062523+0.j), ('IIZZ',  0.17441288+0.j),
#         ('XXYY', -0.04530262+0.j),
#         ('XYYX',  0.04530262+0.j),
#         ('YXXY',  0.04530262+0.j),
#         ('YYXX', -0.04530262+0.j)
#     ]
# )
hamiltonian = SparsePauliOp.from_list(
    [('XXYY', -0.04530262+0.j)])

# %% [markdown]
# $H = Y_0Y_1X_2X_3$

# %%
ansatz = EfficientSU2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp", reverse_bits=False)

# %%
# ansatz = EfficientSU2(hamiltonian.num_qubits)
# ansatz.sdg([0,1])
# ansatz.h([0,1,2,3])
# ansatz.measure_all()
# ansatz.decompose().draw(style='iqp', reverse_bits=False)

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 32

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# #### Cost Function

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    print(result[0].data.evs)
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
np.random.seed(42)
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([2.35330497, 5.97351416, 4.59925358, 3.76148219, 0.98029403,
#        0.98014248, 0.3649501 , 5.44234523, 3.77691701, 4.44895122,
#        0.12933619, 6.09412333, 5.23039137, 1.33416598, 1.14243996,
#        1.15236452, 1.91161039, 3.2971419 , 2.71399059, 1.82984665,
#        3.84438512, 0.87646578, 1.83559896, 2.30191935, 2.86557222,
#        4.93340606, 1.25458737, 3.23103027, 3.72225051, 0.29185655,
#        3.81731689, 1.07143467])

# %%
estimator = Estimator(backend=AerSimulator())
estimator.options.seed_estimator = 10
print(estimator.options.seed_estimator)
# Out:
# 10

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 1000
    estimator.options.seed_estimator = 10

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# [-0.02541636]
# Iters. done: 1 [Current cost: -0.025416362490234375]
# [-0.02371309]
# Iters. done: 2 [Current cost: -0.02371309015625]
# [-0.01904568]
# Iters. done: 3 [Current cost: -0.019045681552734377]
# [-0.02495183]
# Iters. done: 4 [Current cost: -0.024951833671875]
# [-0.0202623]
# Iters. done: 5 [Current cost: -0.0202623046484375]
# [-0.01838207]
# Iters. done: 6 [Current cost: -0.018382068955078126]
# [-0.02552696]
# Iters. done: 7 [Current cost: -0.02552696458984375]
# [-0.01517461]
# Iters. done: 8 [Current cost: -0.015174608066406251]
# [-0.01479856]
# Iters. done: 9 [Current cost: -0.014798560927734376]
# [-0.00559647]
# Iters. done: 10 [Current cost: -0.005596466240234375]
# [-0.0261021]
# Iters. done: 11 [Current cost: -0.026102095507812503]
# [-0.0218771]
# Iters. done: 12 [Current cost: -0.021877095302734375]
# [-0.00975511]
# Iters. done: 13 [Current cost: -0.009755105185546875]
# [-0.02692055]
# Iters. done: 14 [Current cost: -0.026920551044921876]
# [-0.01621427]
# Iters. done: 15 [Current cost: -0.016214267802734376]
# [-0.01880236]
# Iters. done: 16 [Current cost: -0.01880235693359375]
# [-0.02097016]
# Iters. done: 17 [Current cost: -0.0209701580859375]
# [-0.01953233]
# Iters. done: 18 [Current cost: -0.019532330791015625]
# [-0.02119136]
# Iters. done: 19 [Current cost: -0.02119136228515625]
# [-0.03006165]
# Iters. done: 20 [Current cost: -0.030061650673828128]
# [-0.01743089]
# Iters. done: 21 [Current cost: -0.0174308908984375]
# [-0.027186]
# Iters. done: 22 [Current cost: -0.027185996083984375]
# [-0.02908835]
# Iters. done: 23 [Current cost: -0.029088352197265625]
# [-0.03214097]
# Iters. done: 24 [Current cost: -0.03214097014648438]
# [-0.02085956]
# Iters. done: 25 [Current cost: -0.020859555986328125]
# [-0.03324699]
# Iters. done: 26 [Current cost: -0.033246991142578126]
# [-0.02835838]
# Iters. done: 27 [Current cost: -0.02835837833984375]
# [-0.01482068]
# Iters. done: 28 [Current cost: -0.01482068134765625]
# [-0.03676414]
# Iters. done: 29 [Current cost: -0.03676413791015625]
# [-0.01258652]
# Iters. done: 30 [Current cost: -0.012586518935546876]
# [-0.0190678]
# Iters. done: 31 [Current cost: -0.01906780197265625]
# [-0.01583822]
# Iters. done: 32 [Current cost: -0.0158382206640625]
# [-0.02043927]
# Iters. done: 33 [Current cost: -0.0204392680078125]
# [-0.03302579]
# Iters. done: 34 [Current cost: -0.03302578694335938]
# [-0.02922107]
# Iters. done: 35 [Current cost: -0.029221074716796875]
# [-0.0166788]
# Iters. done: 36 [Current cost: -0.016678796621093752]
# [-0.03256126]
# Iters. done: 37 [Current cost: -0.032561258125]
# [-0.03003953]
# Iters. done: 38 [Current cost: -0.030039530253906252]
# [-0.03304791]
# Iters. done: 39 [Current cost: -0.033047907363281254]
# [-0.02961924]
# Iters. done: 40 [Current cost: -0.029619242275390627]
# [-0.03658717]
# Iters. done: 41 [Current cost: -0.036587174550781254]
# [-0.02990681]
# Iters. done: 42 [Current cost: -0.029906807734375002]
# [-0.03457422]
# Iters. done: 43 [Current cost: -0.03457421633789062]
# [-0.03304791]
# Iters. done: 44 [Current cost: -0.033047907363281254]
# [-0.0336894]
# Iters. done: 45 [Current cost: -0.03368939954101562]
# [-0.03041558]
# Iters. done: 46 [Current cost: -0.030415577392578125]
# [-0.03459634]
# Iters. done: 47 [Current cost: -0.0345963367578125]
# [-0.02908835]
# Iters. done: 48 [Current cost: -0.029088352197265625]
# [-0.03326911]
# Iters. done: 49 [Current cost: -0.0332691115625]
# [-0.03722867]
# Iters. done: 50 [Current cost: -0.03722866672851562]
# [-0.03800288]
# Iters. done: 51 [Current cost: -0.03800288142578125]
# [-0.02844686]
# Iters. done: 52 [Current cost: -0.028446860019531253]
# [-0.03800288]
# Iters. done: 53 [Current cost: -0.03800288142578125]
# [-0.02882291]
# Iters. done: 54 [Current cost: -0.028822907158203126]
# [-0.03169856]
# Iters. done: 55 [Current cost: -0.031698561748046875]
# [-0.01716545]
# Iters. done: 56 [Current cost: -0.017165445859375]
# [-0.03722867]
# Iters. done: 57 [Current cost: -0.03722866672851562]
# [-0.02638966]
# Iters. done: 58 [Current cost: -0.026389660966796877]
# [-0.03636597]
# Iters. done: 59 [Current cost: -0.0363659703515625]
# [-0.02720812]
# Iters. done: 60 [Current cost: -0.02720811650390625]
# [-0.03413181]
# Iters. done: 61 [Current cost: -0.034131807939453127]
# [-0.03862225]
# Iters. done: 62 [Current cost: -0.038622253183593754]
# [-0.03311427]
# Iters. done: 63 [Current cost: -0.03311426862304687]
# [-0.0376932]
# Iters. done: 64 [Current cost: -0.037693195546875]
# [-0.03452998]
# Iters. done: 65 [Current cost: -0.03452997549804688]
# [-0.0376932]
# Iters. done: 66 [Current cost: -0.037693195546875]
# [-0.03753835]
# Iters. done: 67 [Current cost: -0.037538352607421874]
# [-0.03634385]
# Iters. done: 68 [Current cost: -0.03634384993164062]
# [-0.03537055]
# Iters. done: 69 [Current cost: -0.03537055145507813]
# [-0.03782592]
# Iters. done: 70 [Current cost: -0.03782591806640625]
# [-0.03448573]
# Iters. done: 71 [Current cost: -0.03448573465820313]
# [-0.03738351]
# Iters. done: 72 [Current cost: -0.03738350966796875]
# [-0.03318063]
# Iters. done: 73 [Current cost: -0.0331806298828125]
# [-0.03320275]
# Iters. done: 74 [Current cost: -0.033202750302734375]
# [-0.03663142]
# Iters. done: 75 [Current cost: -0.036631415390625]
# [-0.03897618]
# Iters. done: 76 [Current cost: -0.038976179902343755]
# [-0.04028128]
# Iters. done: 77 [Current cost: -0.040281284677734376]
# [-0.03879922]
# Iters. done: 78 [Current cost: -0.03879921654296875]
# [-0.03537055]
# Iters. done: 79 [Current cost: -0.03537055145507813]
# [-0.04052461]
# Iters. done: 80 [Current cost: -0.040524609296875]
# [-0.03654293]
# Iters. done: 81 [Current cost: -0.0365429337109375]
# [-0.03999372]
# Iters. done: 82 [Current cost: -0.03999371921875]
# [-0.03906466]
# Iters. done: 83 [Current cost: -0.03906466158203125]
# [-0.03961767]
# Iters. done: 84 [Current cost: -0.039617672080078124]
# [-0.03988312]
# Iters. done: 85 [Current cost: -0.039883117119140624]
# [-0.03831257]
# Iters. done: 86 [Current cost: -0.0383125673046875]
# [-0.03939647]
# Iters. done: 87 [Current cost: -0.039396467880859376]
# [-0.04165275]
# Iters. done: 88 [Current cost: -0.041652750712890624]
# [-0.03665354]
# Iters. done: 89 [Current cost: -0.036653535810546874]
# [-0.04134306]
# Iters. done: 90 [Current cost: -0.04134306483398437]
# [-0.04152003]
# Iters. done: 91 [Current cost: -0.04152002819335938]
# [-0.04182971]
# Iters. done: 92 [Current cost: -0.04182971407226563]
# [-0.04132094]
# Iters. done: 93 [Current cost: -0.041320944414062505]
# [-0.04229424]
# Iters. done: 94 [Current cost: -0.042294242890625]
# [-0.04218364]
# Iters. done: 95 [Current cost: -0.04218364079101563]
# [-0.04218364]
# Iters. done: 96 [Current cost: -0.04218364079101563]
# [-0.04171911]
# Iters. done: 97 [Current cost: -0.04171911197265625]
# [-0.04169699]
# Iters. done: 98 [Current cost: -0.041696991552734375]
# [-0.04253757]
# Iters. done: 99 [Current cost: -0.042537567509765624]
# [-0.04218364]
# Iters. done: 100 [Current cost: -0.04218364079101563]
# [-0.04229424]
# Iters. done: 101 [Current cost: -0.042294242890625]
# [-0.04087854]
# Iters. done: 102 [Current cost: -0.040878536015625]
# [-0.04185183]
# Iters. done: 103 [Current cost: -0.041851834492187504]
# [-0.0410555]
# Iters. done: 104 [Current cost: -0.041055499375]
# [-0.04309058]
# Iters. done: 105 [Current cost: -0.043090578007812505]
# [-0.04180759]
# Iters. done: 106 [Current cost: -0.04180759365234375]
# [-0.04313482]
# Iters. done: 107 [Current cost: -0.04313481884765625]
# [-0.04174123]
# Iters. done: 108 [Current cost: -0.041741232392578126]
# [-0.04342238]
# Iters. done: 109 [Current cost: -0.043422384306640624]
# [-0.0423606]
# Iters. done: 110 [Current cost: -0.04236060415039063]
# [-0.04293574]
# Iters. done: 111 [Current cost: -0.042935735068359376]
# [-0.0430021]
# Iters. done: 112 [Current cost: -0.043002096328125]
# [-0.04317906]
# Iters. done: 113 [Current cost: -0.0431790596875]
# [-0.04222788]
# Iters. done: 114 [Current cost: -0.042227881630859374]
# [-0.04280301]
# Iters. done: 115 [Current cost: -0.04280301254882812]
# [-0.04373207]
# Iters. done: 116 [Current cost: -0.043732070185546874]
# [-0.04359935]
# Iters. done: 117 [Current cost: -0.04359934766601563]
# [-0.04346663]
# Iters. done: 118 [Current cost: -0.043466625146484375]
# [-0.04370995]
# Iters. done: 119 [Current cost: -0.043709949765625]
# [-0.0434445]
# Iters. done: 120 [Current cost: -0.0434445047265625]
# [-0.04399752]
# Iters. done: 121 [Current cost: -0.043997515224609374]
# [-0.04280301]
# Iters. done: 122 [Current cost: -0.04280301254882812]
# [-0.04397539]
# Iters. done: 123 [Current cost: -0.043975394804687505]
# [-0.04395327]
# Iters. done: 124 [Current cost: -0.04395327438476563]
# [-0.04359935]
# Iters. done: 125 [Current cost: -0.04359934766601563]
# [-0.04388691]
# Iters. done: 126 [Current cost: -0.043886913125]
# [-0.04415236]
# Iters. done: 127 [Current cost: -0.0441523581640625]
# [-0.04386479]
# Iters. done: 128 [Current cost: -0.04386479270507813]
# [-0.04353299]
# Iters. done: 129 [Current cost: -0.04353298640625]
# [-0.04359935]
# Iters. done: 130 [Current cost: -0.04359934766601563]
# [-0.04328966]
# Iters. done: 131 [Current cost: -0.04328966178710938]
# [-0.04457265]
# Iters. done: 132 [Current cost: -0.04457264614257812]
# [-0.04421872]
# Iters. done: 133 [Current cost: -0.04421871942382813]
# [-0.04342238]
# Iters. done: 134 [Current cost: -0.043422384306640624]
# [-0.04382055]
# Iters. done: 135 [Current cost: -0.043820551865234376]
# [-0.04426296]
# Iters. done: 136 [Current cost: -0.04426296026367188]
# [-0.04448416]
# Iters. done: 137 [Current cost: -0.04448416446289063]
# [-0.04388691]
# Iters. done: 138 [Current cost: -0.043886913125]
# [-0.04397539]
# Iters. done: 139 [Current cost: -0.043975394804687505]
# [-0.04353299]
# Iters. done: 140 [Current cost: -0.04353298640625]
# [-0.04357723]
# Iters. done: 141 [Current cost: -0.04357722724609375]
# [-0.0431127]
# Iters. done: 142 [Current cost: -0.043112698427734374]
# [-0.04395327]
# Iters. done: 143 [Current cost: -0.04395327438476563]
# [-0.04452841]
# Iters. done: 144 [Current cost: -0.04452840530273438]
# [-0.04382055]
# Iters. done: 145 [Current cost: -0.043820551865234376]
# [-0.04415236]
# Iters. done: 146 [Current cost: -0.0441523581640625]
# [-0.04452841]
# Iters. done: 147 [Current cost: -0.04452840530273438]
# [-0.04443992]
# Iters. done: 148 [Current cost: -0.04443992362304688]
# [-0.04435144]
# Iters. done: 149 [Current cost: -0.044351441943359375]
# [-0.0443072]
# Iters. done: 150 [Current cost: -0.044307201103515624]
# [-0.04448416]
# Iters. done: 151 [Current cost: -0.04448416446289063]
# [-0.04428508]
# Iters. done: 152 [Current cost: -0.04428508068359375]
# [-0.04401964]
# Iters. done: 153 [Current cost: -0.04401963564453125]
# [-0.04457265]
# Iters. done: 154 [Current cost: -0.04457264614257812]
# [-0.04455053]
# Iters. done: 155 [Current cost: -0.044550525722656255]
# [-0.04435144]
# Iters. done: 156 [Current cost: -0.044351441943359375]
# [-0.04446204]
# Iters. done: 157 [Current cost: -0.04446204404296875]
# [-0.04410812]
# Iters. done: 158 [Current cost: -0.04410811732421875]
# [-0.04443992]
# Iters. done: 159 [Current cost: -0.04443992362304688]
# [-0.04426296]
# Iters. done: 160 [Current cost: -0.04426296026367188]
# [-0.0444178]
# Iters. done: 161 [Current cost: -0.044417803203125]
# [-0.04435144]
# Iters. done: 162 [Current cost: -0.044351441943359375]
# [-0.04415236]
# Iters. done: 163 [Current cost: -0.0441523581640625]
# [-0.04428508]
# Iters. done: 164 [Current cost: -0.04428508068359375]
# [-0.0444178]
# Iters. done: 165 [Current cost: -0.044417803203125]
# [-0.04446204]
# Iters. done: 166 [Current cost: -0.04446204404296875]
# [-0.04428508]
# Iters. done: 167 [Current cost: -0.04428508068359375]
# [-0.04450628]
# Iters. done: 168 [Current cost: -0.044506284882812504]
# [-0.04437356]
# Iters. done: 169 [Current cost: -0.04437356236328125]
# [-0.04428508]
# Iters. done: 170 [Current cost: -0.04428508068359375]
# [-0.04455053]
# Iters. done: 171 [Current cost: -0.044550525722656255]
# [-0.04468325]
# Iters. done: 172 [Current cost: -0.0446832482421875]
# [-0.04426296]
# Iters. done: 173 [Current cost: -0.04426296026367188]
# [-0.04432932]
# Iters. done: 174 [Current cost: -0.0443293215234375]
# [-0.044086]
# Iters. done: 175 [Current cost: -0.044085996904296876]
# [-0.04443992]
# Iters. done: 176 [Current cost: -0.04443992362304688]
# [-0.04435144]
# Iters. done: 177 [Current cost: -0.044351441943359375]
# [-0.04439568]
# Iters. done: 178 [Current cost: -0.044395682783203126]
# [-0.04432932]
# Iters. done: 179 [Current cost: -0.0443293215234375]
# [-0.04417448]
# Iters. done: 180 [Current cost: -0.04417447858398438]
# [-0.04450628]
# Iters. done: 181 [Current cost: -0.044506284882812504]
# [-0.04428508]
# Iters. done: 182 [Current cost: -0.04428508068359375]
# [-0.04443992]
# Iters. done: 183 [Current cost: -0.04443992362304688]
# [-0.04448416]
# Iters. done: 184 [Current cost: -0.04448416446289063]
# [-0.0443072]
# Iters. done: 185 [Current cost: -0.044307201103515624]
# [-0.04448416]
# Iters. done: 186 [Current cost: -0.04448416446289063]
# [-0.04421872]
# Iters. done: 187 [Current cost: -0.04421871942382813]
# [-0.04448416]
# Iters. done: 188 [Current cost: -0.04448416446289063]
# [-0.04432932]
# Iters. done: 189 [Current cost: -0.0443293215234375]
# [-0.04466113]
# Iters. done: 190 [Current cost: -0.044661127822265625]
# [-0.04428508]
# Iters. done: 191 [Current cost: -0.04428508068359375]
# [-0.04439568]
# Iters. done: 192 [Current cost: -0.044395682783203126]
# [-0.04426296]
# Iters. done: 193 [Current cost: -0.04426296026367188]
# [-0.04470537]
# Iters. done: 194 [Current cost: -0.04470536866210938]
# [-0.0444178]
# Iters. done: 195 [Current cost: -0.044417803203125]
# [-0.04443992]
# Iters. done: 196 [Current cost: -0.04443992362304688]
# [-0.0443072]
# Iters. done: 197 [Current cost: -0.044307201103515624]
# [-0.04455053]
# Iters. done: 198 [Current cost: -0.044550525722656255]
# [-0.04428508]
# Iters. done: 199 [Current cost: -0.04428508068359375]
# [-0.04452841]
# Iters. done: 200 [Current cost: -0.04452840530273438]
# [-0.04443992]
# Iters. done: 201 [Current cost: -0.04443992362304688]
# [-0.04470537]
# Iters. done: 202 [Current cost: -0.04470536866210938]
# [-0.04428508]
# Iters. done: 203 [Current cost: -0.04428508068359375]
# [-0.04417448]
# Iters. done: 204 [Current cost: -0.04417447858398438]
# [-0.04450628]
# Iters. done: 205 [Current cost: -0.044506284882812504]
# [-0.04421872]
# Iters. done: 206 [Current cost: -0.04421871942382813]
# [-0.04421872]
# Iters. done: 207 [Current cost: -0.04421871942382813]
# [-0.04417448]
# Iters. done: 208 [Current cost: -0.04417447858398438]
# [-0.04443992]
# Iters. done: 209 [Current cost: -0.04443992362304688]
# [-0.04437356]
# Iters. done: 210 [Current cost: -0.04437356236328125]
# [-0.04435144]
# Iters. done: 211 [Current cost: -0.044351441943359375]
# [-0.04413024]
# Iters. done: 212 [Current cost: -0.04413023774414063]
# [-0.04443992]
# Iters. done: 213 [Current cost: -0.04443992362304688]
# [-0.04437356]
# Iters. done: 214 [Current cost: -0.04437356236328125]
# [-0.04432932]
# Iters. done: 215 [Current cost: -0.0443293215234375]
# [-0.0444178]
# Iters. done: 216 [Current cost: -0.044417803203125]
# [-0.04424084]
# Iters. done: 217 [Current cost: -0.044240839843750004]
# [-0.04455053]
# Iters. done: 218 [Current cost: -0.044550525722656255]
# [-0.04435144]
# Iters. done: 219 [Current cost: -0.044351441943359375]
# [-0.0443072]
# Iters. done: 220 [Current cost: -0.044307201103515624]
# [-0.04443992]
# Iters. done: 221 [Current cost: -0.04443992362304688]
# [-0.04424084]
# Iters. done: 222 [Current cost: -0.044240839843750004]
# [-0.0443072]
# Iters. done: 223 [Current cost: -0.044307201103515624]
# [-0.04435144]
# Iters. done: 224 [Current cost: -0.044351441943359375]
# [-0.04437356]
# Iters. done: 225 [Current cost: -0.04437356236328125]
# [-0.0444178]
# Iters. done: 226 [Current cost: -0.044417803203125]
# [-0.04439568]
# Iters. done: 227 [Current cost: -0.044395682783203126]
# [-0.04421872]
# Iters. done: 228 [Current cost: -0.04421871942382813]
# [-0.04404176]
# Iters. done: 229 [Current cost: -0.044041756064453125]
# [-0.04435144]
# Iters. done: 230 [Current cost: -0.044351441943359375]
# [-0.0444178]
# Iters. done: 231 [Current cost: -0.044417803203125]
# [-0.0444178]
# Iters. done: 232 [Current cost: -0.044417803203125]
# [-0.04432932]
# Iters. done: 233 [Current cost: -0.0443293215234375]
# [-0.04443992]
# Iters. done: 234 [Current cost: -0.04443992362304688]
# [-0.0443072]
# Iters. done: 235 [Current cost: -0.044307201103515624]
# [-0.04452841]
# Iters. done: 236 [Current cost: -0.04452840530273438]
# [-0.04428508]
# Iters. done: 237 [Current cost: -0.04428508068359375]
# [-0.04448416]
# Iters. done: 238 [Current cost: -0.04448416446289063]
# [-0.04437356]
# Iters. done: 239 [Current cost: -0.04437356236328125]
# [-0.04424084]
# Iters. done: 240 [Current cost: -0.044240839843750004]
# [-0.04428508]
# Iters. done: 241 [Current cost: -0.04428508068359375]
# [-0.04443992]
# Iters. done: 242 [Current cost: -0.04443992362304688]
# [-0.04455053]
# Iters. done: 243 [Current cost: -0.044550525722656255]
# [-0.04443992]
# Iters. done: 244 [Current cost: -0.04443992362304688]
# [-0.04459477]
# Iters. done: 245 [Current cost: -0.0445947665625]
# [-0.04432932]
# Iters. done: 246 [Current cost: -0.0443293215234375]
# [-0.04443992]
# Iters. done: 247 [Current cost: -0.04443992362304688]
# [-0.044086]
# Iters. done: 248 [Current cost: -0.044085996904296876]
# [-0.04446204]
# Iters. done: 249 [Current cost: -0.04446204404296875]
# [-0.04446204]
# Iters. done: 250 [Current cost: -0.04446204404296875]
# [-0.04448416]
# Iters. done: 251 [Current cost: -0.04448416446289063]
# [-0.04452841]
# Iters. done: 252 [Current cost: -0.04452840530273438]
# [-0.0444178]
# Iters. done: 253 [Current cost: -0.044417803203125]
# [-0.04448416]
# Iters. done: 254 [Current cost: -0.04448416446289063]
# [-0.04448416]
# Iters. done: 255 [Current cost: -0.04448416446289063]
# [-0.04452841]
# Iters. done: 256 [Current cost: -0.04452840530273438]
# [-0.0443072]
# Iters. done: 257 [Current cost: -0.044307201103515624]
# [-0.04437356]
# Iters. done: 258 [Current cost: -0.04437356236328125]
# [-0.04428508]
# Iters. done: 259 [Current cost: -0.04428508068359375]
# [-0.04457265]
# Iters. done: 260 [Current cost: -0.04457264614257812]
# [-0.04439568]
# Iters. done: 261 [Current cost: -0.044395682783203126]
# [-0.0444178]
# Iters. done: 262 [Current cost: -0.044417803203125]
# [-0.04435144]
# Iters. done: 263 [Current cost: -0.044351441943359375]
# [-0.04439568]
# Iters. done: 264 [Current cost: -0.044395682783203126]
# [-0.04439568]
# Iters. done: 265 [Current cost: -0.044395682783203126]
# [-0.04424084]
# Iters. done: 266 [Current cost: -0.044240839843750004]
# [-0.0443072]
# Iters. done: 267 [Current cost: -0.044307201103515624]
# [-0.04452841]
# Iters. done: 268 [Current cost: -0.04452840530273438]
# [-0.04432932]
# Iters. done: 269 [Current cost: -0.0443293215234375]
# [-0.04439568]
# Iters. done: 270 [Current cost: -0.044395682783203126]
# [-0.04413024]
# Iters. done: 271 [Current cost: -0.04413023774414063]
# [-0.04435144]
# Iters. done: 272 [Current cost: -0.044351441943359375]
# [-0.04432932]
# Iters. done: 273 [Current cost: -0.0443293215234375]
# [-0.04435144]
# Iters. done: 274 [Current cost: -0.044351441943359375]
# [-0.0444178]
# Iters. done: 275 [Current cost: -0.044417803203125]
# [-0.04437356]
# Iters. done: 276 [Current cost: -0.04437356236328125]
# [-0.04457265]
# Iters. done: 277 [Current cost: -0.04457264614257812]
# [-0.04417448]
# Iters. done: 278 [Current cost: -0.04417447858398438]
# [-0.04424084]
# Iters. done: 279 [Current cost: -0.044240839843750004]
# [-0.04428508]
# Iters. done: 280 [Current cost: -0.04428508068359375]
# [-0.04437356]
# Iters. done: 281 [Current cost: -0.04437356236328125]
# [-0.0441966]
# Iters. done: 282 [Current cost: -0.04419659900390625]
# [-0.04432932]
# Iters. done: 283 [Current cost: -0.0443293215234375]
# [-0.0444178]
# Iters. done: 284 [Current cost: -0.044417803203125]
# [-0.04426296]
# Iters. done: 285 [Current cost: -0.04426296026367188]
# [-0.04435144]
# Iters. done: 286 [Current cost: -0.044351441943359375]
# [-0.04413024]
# Iters. done: 287 [Current cost: -0.04413023774414063]
# [-0.0443072]
# Iters. done: 288 [Current cost: -0.044307201103515624]
# [-0.04450628]
# Iters. done: 289 [Current cost: -0.044506284882812504]
# [-0.04437356]
# Iters. done: 290 [Current cost: -0.04437356236328125]
# [-0.04448416]
# Iters. done: 291 [Current cost: -0.04448416446289063]
# [-0.04435144]
# Iters. done: 292 [Current cost: -0.044351441943359375]
# [-0.04448416]
# Iters. done: 293 [Current cost: -0.04448416446289063]
# [-0.04439568]
# Iters. done: 294 [Current cost: -0.044395682783203126]
# [-0.04424084]
# Iters. done: 295 [Current cost: -0.044240839843750004]
# [-0.04463901]
# Iters. done: 296 [Current cost: -0.04463900740234375]
# [-0.04446204]
# Iters. done: 297 [Current cost: -0.04446204404296875]
# [-0.04466113]
# Iters. done: 298 [Current cost: -0.044661127822265625]
# [-0.0444178]
# Iters. done: 299 [Current cost: -0.044417803203125]
# [-0.0443072]
# Iters. done: 300 [Current cost: -0.044307201103515624]
# [-0.0443072]
# Iters. done: 301 [Current cost: -0.044307201103515624]
# [-0.04455053]
# Iters. done: 302 [Current cost: -0.044550525722656255]
# [-0.04432932]
# Iters. done: 303 [Current cost: -0.0443293215234375]
# [-0.04450628]
# Iters. done: 304 [Current cost: -0.044506284882812504]
# [-0.04435144]
# Iters. done: 305 [Current cost: -0.044351441943359375]
# [-0.04439568]
# Iters. done: 306 [Current cost: -0.044395682783203126]
# [-0.04466113]
# Iters. done: 307 [Current cost: -0.044661127822265625]
# [-0.04459477]
# Iters. done: 308 [Current cost: -0.0445947665625]
# [-0.04432932]
# Iters. done: 309 [Current cost: -0.0443293215234375]
# [-0.04413024]
# Iters. done: 310 [Current cost: -0.04413023774414063]
# [-0.0443072]
# Iters. done: 311 [Current cost: -0.044307201103515624]
# [-0.04443992]
# Iters. done: 312 [Current cost: -0.04443992362304688]
# [-0.04432932]
# Iters. done: 313 [Current cost: -0.0443293215234375]
# [-0.0443072]
# Iters. done: 314 [Current cost: -0.044307201103515624]
# [-0.04461689]
# Iters. done: 315 [Current cost: -0.044616886982421874]
# [-0.04437356]
# Iters. done: 316 [Current cost: -0.04437356236328125]
# [-0.04413024]
# Iters. done: 317 [Current cost: -0.04413023774414063]
# [-0.0444178]
# Iters. done: 318 [Current cost: -0.044417803203125]
# [-0.04459477]
# Iters. done: 319 [Current cost: -0.0445947665625]
# [-0.04455053]
# Iters. done: 320 [Current cost: -0.044550525722656255]
# [-0.04437356]
# Iters. done: 321 [Current cost: -0.04437356236328125]
# [-0.04439568]
# Iters. done: 322 [Current cost: -0.044395682783203126]
# [-0.04452841]
# Iters. done: 323 [Current cost: -0.04452840530273438]
# [-0.04457265]
# Iters. done: 324 [Current cost: -0.04457264614257812]

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
ax.set_ylim(-0.05,0)
plt.draw()

# %%
# with Session(backend=backend) as session:
#     estimator = Estimator(session=session)
#     estimator.options.default_shots = 1000
#     estimator.options.seed_estimator = 10

#     res = minimize(
#         cost_func,
#         x0,
#         args=(ansatz_isa, hamiltonian_isa, estimator),
#         method="cobyla",
#     )

# %%
# fig, ax = plt.subplots()
# ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
# ax.set_xlabel("Iterations")
# ax.set_ylabel("Cost")
# plt.draw()
