# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import AerSimulator

# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService(channel="ibm_quantum")
# backend = service.least_busy(operational=True, simulator=False)
backend = AerSimulator()
backend
# Out:
# AerSimulator('aer_simulator')

# %%
hamiltonian = SparsePauliOp.from_list(
    [("YZ", 0.3980), ("IZ", -0.3980), ("ZI", -0.0113), ("XX", 0.1810)]
)
# hamiltonian = SparsePauliOp.from_list(
#     [("YZ", 1), ("ZI", 1), ("ZZ", 1), ("XX", 1)]
# )

# %%
ansatz = EfficientSU2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp")

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 16

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# #### Cost Function

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    print(result[0].data.evs)
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
np.random.seed(42)
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([2.35330497, 5.97351416, 4.59925358, 3.76148219, 0.98029403,
#        0.98014248, 0.3649501 , 5.44234523, 3.77691701, 4.44895122,
#        0.12933619, 6.09412333, 5.23039137, 1.33416598, 1.14243996,
#        1.15236452])

# %%
estimator = Estimator(backend=AerSimulator())
estimator.options.seed_estimator = 10
print(estimator.options.seed_estimator)
# Out:
# 10

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 1000
    estimator.options.seed_estimator = 10

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# [0.32004336]
# Iters. done: 1 [Current cost: 0.320043359375]
# [-0.01220293]
# Iters. done: 2 [Current cost: -0.012202929687500003]
# [-0.24903042]
# Iters. done: 3 [Current cost: -0.24903041992187502]
# [-0.15847241]
# Iters. done: 4 [Current cost: -0.15847241210937502]
# [0.06900288]
# Iters. done: 5 [Current cost: 0.069002880859375]
# [-0.0233645]
# Iters. done: 6 [Current cost: -0.023364501953125]
# [-0.47291519]
# Iters. done: 7 [Current cost: -0.47291518554687506]
# [-0.50481562]
# Iters. done: 8 [Current cost: -0.504815625]
# [-0.52131099]
# Iters. done: 9 [Current cost: -0.521310986328125]
# [-0.38256816]
# Iters. done: 10 [Current cost: -0.38256816406249994]
# [-0.47918403]
# Iters. done: 11 [Current cost: -0.4791840332031251]
# [-0.49591997]
# Iters. done: 12 [Current cost: -0.495919970703125]
# [-0.34873472]
# Iters. done: 13 [Current cost: -0.348734716796875]
# [-0.38984844]
# Iters. done: 14 [Current cost: -0.3898484375]
# [-0.56650747]
# Iters. done: 15 [Current cost: -0.566507470703125]
# [-0.62276748]
# Iters. done: 16 [Current cost: -0.62276748046875]
# [-0.23584453]
# Iters. done: 17 [Current cost: -0.23584453125]
# [-0.55574468]
# Iters. done: 18 [Current cost: -0.5557446777343751]
# [-0.6913085]
# Iters. done: 19 [Current cost: -0.6913084960937501]
# [-0.57184492]
# Iters. done: 20 [Current cost: -0.5718449218750001]
# [-0.70083735]
# Iters. done: 21 [Current cost: -0.700837353515625]
# [-0.54113159]
# Iters. done: 22 [Current cost: -0.5411315917968751]
# [-0.62569976]
# Iters. done: 23 [Current cost: -0.6256997558593751]
# [-0.59836636]
# Iters. done: 24 [Current cost: -0.598366357421875]
# [-0.63792949]
# Iters. done: 25 [Current cost: -0.6379294921875]
# [-0.49757588]
# Iters. done: 26 [Current cost: -0.4975758789062501]
# [-0.73834814]
# Iters. done: 27 [Current cost: -0.73834814453125]
# [-0.71329214]
# Iters. done: 28 [Current cost: -0.713292138671875]
# [-0.77236519]
# Iters. done: 29 [Current cost: -0.7723651855468752]
# [-0.59806504]
# Iters. done: 30 [Current cost: -0.5980650390625]
# [-0.79699272]
# Iters. done: 31 [Current cost: -0.7969927246093751]
# [-0.65515313]
# Iters. done: 32 [Current cost: -0.6551531250000001]
# [-0.72996782]
# Iters. done: 33 [Current cost: -0.7299678222656251]
# [-0.7921061]
# Iters. done: 34 [Current cost: -0.7921061035156252]
# [-0.76094033]
# Iters. done: 35 [Current cost: -0.76094033203125]
# [-0.79793306]
# Iters. done: 36 [Current cost: -0.7979330566406251]
# [-0.81705381]
# Iters. done: 37 [Current cost: -0.81705380859375]
# [-0.80714238]
# Iters. done: 38 [Current cost: -0.8071423828125]
# [-0.79445625]
# Iters. done: 39 [Current cost: -0.7944562500000001]
# [-0.81531743]
# Iters. done: 40 [Current cost: -0.8153174316406251]
# [-0.77980649]
# Iters. done: 41 [Current cost: -0.7798064941406252]
# [-0.80753716]
# Iters. done: 42 [Current cost: -0.807537158203125]
# [-0.81186738]
# Iters. done: 43 [Current cost: -0.8118673828125]
# [-0.81571597]
# Iters. done: 44 [Current cost: -0.815715966796875]
# [-0.78815137]
# Iters. done: 45 [Current cost: -0.7881513671875]
# [-0.80885898]
# Iters. done: 46 [Current cost: -0.808858984375]
# [-0.77507627]
# Iters. done: 47 [Current cost: -0.7750762695312501]
# [-0.82054316]
# Iters. done: 48 [Current cost: -0.8205431640625]
# [-0.80997827]
# Iters. done: 49 [Current cost: -0.8099782714843751]
# [-0.79723105]
# Iters. done: 50 [Current cost: -0.7972310546875]
# [-0.81319238]
# Iters. done: 51 [Current cost: -0.8131923828125001]
# [-0.8233019]
# Iters. done: 52 [Current cost: -0.8233019042968751]
# [-0.82663726]
# Iters. done: 53 [Current cost: -0.8266372558593751]
# [-0.82004019]
# Iters. done: 54 [Current cost: -0.8200401855468751]
# [-0.81462847]
# Iters. done: 55 [Current cost: -0.814628466796875]
# [-0.80261382]
# Iters. done: 56 [Current cost: -0.8026138183593751]
# [-0.81446665]
# Iters. done: 57 [Current cost: -0.8144666503906252]
# [-0.78534014]
# Iters. done: 58 [Current cost: -0.7853401367187501]
# [-0.81788853]
# Iters. done: 59 [Current cost: -0.8178885253906251]
# [-0.79950464]
# Iters. done: 60 [Current cost: -0.7995046386718752]
# [-0.80857354]
# Iters. done: 61 [Current cost: -0.8085735351562501]
# [-0.82396206]
# Iters. done: 62 [Current cost: -0.8239620605468752]
# [-0.80801006]
# Iters. done: 63 [Current cost: -0.8080100585937501]
# [-0.81567529]
# Iters. done: 64 [Current cost: -0.8156752929687501]
# [-0.81702139]
# Iters. done: 65 [Current cost: -0.81702138671875]
# [-0.81789326]
# Iters. done: 66 [Current cost: -0.8178932617187502]
# [-0.81811421]
# Iters. done: 67 [Current cost: -0.818114208984375]
# [-0.80820723]
# Iters. done: 68 [Current cost: -0.8082072265625]
# [-0.81933281]
# Iters. done: 69 [Current cost: -0.8193328125]
# [-0.8150041]
# Iters. done: 70 [Current cost: -0.8150041015625]
# [-0.82233813]
# Iters. done: 71 [Current cost: -0.8223381347656251]
# [-0.81200835]
# Iters. done: 72 [Current cost: -0.812008349609375]
# [-0.82411177]
# Iters. done: 73 [Current cost: -0.824111767578125]
# [-0.81412983]
# Iters. done: 74 [Current cost: -0.814129833984375]
# [-0.82065977]
# Iters. done: 75 [Current cost: -0.8206597656250001]
# [-0.81491128]
# Iters. done: 76 [Current cost: -0.814911279296875]
# [-0.81550801]
# Iters. done: 77 [Current cost: -0.8155080078125]
# [-0.81877432]
# Iters. done: 78 [Current cost: -0.81877431640625]
# [-0.81780112]
# Iters. done: 79 [Current cost: -0.8178011230468751]
# [-0.81642993]
# Iters. done: 80 [Current cost: -0.8164299316406249]
# [-0.81439458]
# Iters. done: 81 [Current cost: -0.814394580078125]
# [-0.81203306]
# Iters. done: 82 [Current cost: -0.8120330566406251]
# [-0.81564316]
# Iters. done: 83 [Current cost: -0.8156431640625]
# [-0.82003901]
# Iters. done: 84 [Current cost: -0.820039013671875]
# [-0.82202632]
# Iters. done: 85 [Current cost: -0.822026318359375]
# [-0.81829312]
# Iters. done: 86 [Current cost: -0.8182931152343751]
# [-0.81223501]
# Iters. done: 87 [Current cost: -0.8122350097656249]
# [-0.81047559]
# Iters. done: 88 [Current cost: -0.8104755859375]
# [-0.81902817]
# Iters. done: 89 [Current cost: -0.8190281738281251]
# [-0.81267017]
# Iters. done: 90 [Current cost: -0.8126701660156251]
# [-0.8199812]
# Iters. done: 91 [Current cost: -0.819981201171875]
# [-0.81409824]
# Iters. done: 92 [Current cost: -0.8140982421875]
# [-0.81548887]
# Iters. done: 93 [Current cost: -0.8154888671874999]
# [-0.81403989]
# Iters. done: 94 [Current cost: -0.8140398925781251]
# [-0.82220259]
# Iters. done: 95 [Current cost: -0.8222025878906251]
# [-0.8161353]
# Iters. done: 96 [Current cost: -0.816135302734375]
# [-0.81719912]
# Iters. done: 97 [Current cost: -0.81719912109375]
# [-0.82431963]
# Iters. done: 98 [Current cost: -0.82431962890625]
# [-0.81624985]
# Iters. done: 99 [Current cost: -0.8162498535156251]
# [-0.8201374]
# Iters. done: 100 [Current cost: -0.8201374023437501]
# [-0.81486782]
# Iters. done: 101 [Current cost: -0.814867822265625]
# [-0.81548853]
# Iters. done: 102 [Current cost: -0.815488525390625]
# [-0.81538013]
# Iters. done: 103 [Current cost: -0.8153801269531251]
# [-0.8196542]
# Iters. done: 104 [Current cost: -0.81965419921875]
# [-0.82188555]
# Iters. done: 105 [Current cost: -0.821885546875]
# [-0.8136748]
# Iters. done: 106 [Current cost: -0.8136748046875]
# [-0.81565386]
# Iters. done: 107 [Current cost: -0.815653857421875]
# [-0.81580425]
# Iters. done: 108 [Current cost: -0.815804248046875]
# [-0.81678179]
# Iters. done: 109 [Current cost: -0.8167817871093751]
# [-0.81804067]
# Iters. done: 110 [Current cost: -0.818040673828125]
# [-0.81952539]
# Iters. done: 111 [Current cost: -0.819525390625]
# [-0.81866577]
# Iters. done: 112 [Current cost: -0.8186657714843751]
# [-0.81951885]
# Iters. done: 113 [Current cost: -0.8195188476562499]
# [-0.81573892]
# Iters. done: 114 [Current cost: -0.815738916015625]
# [-0.81688906]
# Iters. done: 115 [Current cost: -0.8168890625]
# [-0.81469854]
# Iters. done: 116 [Current cost: -0.81469853515625]
# [-0.81867803]
# Iters. done: 117 [Current cost: -0.8186780273437501]
# [-0.81019404]
# Iters. done: 118 [Current cost: -0.81019404296875]
# [-0.82190674]
# Iters. done: 119 [Current cost: -0.82190673828125]
# [-0.82118931]
# Iters. done: 120 [Current cost: -0.8211893066406251]
# [-0.81868164]
# Iters. done: 121 [Current cost: -0.8186816406250002]
# [-0.82407178]
# Iters. done: 122 [Current cost: -0.82407177734375]
# [-0.81500874]
# Iters. done: 123 [Current cost: -0.815008740234375]
# [-0.82988511]
# Iters. done: 124 [Current cost: -0.829885107421875]
# [-0.81723667]
# Iters. done: 125 [Current cost: -0.817236669921875]
# [-0.81507695]
# Iters. done: 126 [Current cost: -0.8150769531250001]
# [-0.81994619]
# Iters. done: 127 [Current cost: -0.8199461914062501]
# [-0.80984771]
# Iters. done: 128 [Current cost: -0.809847705078125]
# [-0.81840742]
# Iters. done: 129 [Current cost: -0.8184074218749999]
# [-0.80362334]
# Iters. done: 130 [Current cost: -0.80362333984375]
# [-0.80861396]
# Iters. done: 131 [Current cost: -0.80861396484375]
# [-0.81049297]
# Iters. done: 132 [Current cost: -0.81049296875]
# [-0.80897627]
# Iters. done: 133 [Current cost: -0.8089762695312501]
# [-0.81003354]
# Iters. done: 134 [Current cost: -0.810033544921875]
# [-0.81808447]
# Iters. done: 135 [Current cost: -0.81808447265625]
# [-0.81754316]
# Iters. done: 136 [Current cost: -0.8175431640625]
# [-0.82111265]
# Iters. done: 137 [Current cost: -0.821112646484375]
# [-0.81187207]
# Iters. done: 138 [Current cost: -0.8118720703125]
# [-0.81044033]
# Iters. done: 139 [Current cost: -0.8104403320312501]
# [-0.81937036]
# Iters. done: 140 [Current cost: -0.819370361328125]
# [-0.82390879]
# Iters. done: 141 [Current cost: -0.8239087890625001]
# [-0.81329648]
# Iters. done: 142 [Current cost: -0.813296484375]
# [-0.8147001]
# Iters. done: 143 [Current cost: -0.8147000976562501]
# [-0.81108638]
# Iters. done: 144 [Current cost: -0.811086376953125]
# [-0.81676875]
# Iters. done: 145 [Current cost: -0.81676875]
# [-0.8155751]
# Iters. done: 146 [Current cost: -0.81557509765625]
# [-0.81465444]
# Iters. done: 147 [Current cost: -0.814654443359375]
# [-0.82230815]
# Iters. done: 148 [Current cost: -0.8223081542968751]
# [-0.81623467]
# Iters. done: 149 [Current cost: -0.8162346679687501]
# [-0.82130308]
# Iters. done: 150 [Current cost: -0.821303076171875]
# [-0.81413848]
# Iters. done: 151 [Current cost: -0.8141384765625]

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 1000
    estimator.options.seed_estimator = 10

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# [0.29580347]
# Iters. done: 152 [Current cost: 0.295803466796875]
# [-0.03006978]
# Iters. done: 153 [Current cost: -0.030069775390624998]
# [-0.24879487]
# Iters. done: 154 [Current cost: -0.248794873046875]
# [-0.18993984]
# Iters. done: 155 [Current cost: -0.18993984375]
# [0.08841162]
# Iters. done: 156 [Current cost: 0.08841162109375002]
# [0.00790537]
# Iters. done: 157 [Current cost: 0.007905371093750002]
# [-0.50071621]
# Iters. done: 158 [Current cost: -0.5007162109375]
# [-0.49557563]
# Iters. done: 159 [Current cost: -0.49557563476562505]
# [-0.64674517]
# Iters. done: 160 [Current cost: -0.646745166015625]
# [-0.54584492]
# Iters. done: 161 [Current cost: -0.545844921875]
# [-0.75433955]
# Iters. done: 162 [Current cost: -0.75433955078125]
# [-0.53322788]
# Iters. done: 163 [Current cost: -0.5332278808593751]
# [-0.5972312]
# Iters. done: 164 [Current cost: -0.597231201171875]
# [-0.59093369]
# Iters. done: 165 [Current cost: -0.5909336914062501]
# [-0.64402769]
# Iters. done: 166 [Current cost: -0.644027685546875]
# [-0.75918906]
# Iters. done: 167 [Current cost: -0.7591890625]
# [-0.54357803]
# Iters. done: 168 [Current cost: -0.5435780273437499]
# [-0.51578271]
# Iters. done: 169 [Current cost: -0.51578271484375]
# [-0.68361973]
# Iters. done: 170 [Current cost: -0.6836197265624999]
# [-0.60103916]
# Iters. done: 171 [Current cost: -0.6010391601562499]
# [-0.76253535]
# Iters. done: 172 [Current cost: -0.7625353515625]
# [-0.61221772]
# Iters. done: 173 [Current cost: -0.612217724609375]
# [-0.78468027]
# Iters. done: 174 [Current cost: -0.7846802734375001]
# [-0.69294116]
# Iters. done: 175 [Current cost: -0.692941162109375]
# [-0.69946875]
# Iters. done: 176 [Current cost: -0.69946875]
# [-0.57957363]
# Iters. done: 177 [Current cost: -0.5795736328125001]
# [-0.76805664]
# Iters. done: 178 [Current cost: -0.768056640625]
# [-0.68354663]
# Iters. done: 179 [Current cost: -0.683546630859375]
# [-0.71652319]
# Iters. done: 180 [Current cost: -0.716523193359375]
# [-0.75091191]
# Iters. done: 181 [Current cost: -0.7509119140625]
# [-0.72369932]
# Iters. done: 182 [Current cost: -0.7236993164062501]
# [-0.78750205]
# Iters. done: 183 [Current cost: -0.78750205078125]
# [-0.77542651]
# Iters. done: 184 [Current cost: -0.775426513671875]
# [-0.75850039]
# Iters. done: 185 [Current cost: -0.7585003906250001]
# [-0.67835063]
# Iters. done: 186 [Current cost: -0.6783506347656251]
# [-0.77733242]
# Iters. done: 187 [Current cost: -0.777332421875]
# [-0.73113535]
# Iters. done: 188 [Current cost: -0.7311353515625]
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[83], line 6
#       3 estimator.options.default_shots = 1000
#       4 estimator.options.seed_estimator = 10
# ----> 6 res = minimize(
#       7     cost_func,
#       8     x0,
#       9     args=(ansatz_isa, hamiltonian_isa, estimator),
#      10     method="cobyla",
#      11 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[78], line 21, in cost_func(params, ansatz, hamiltonian, estimator)
#       8 """Return estimate of energy from estimator
#       9
#      10 Parameters:
#    (...)
#      18     float: Energy estimate
#      19 """
#      20 pub = (ansatz, [hamiltonian], [params])
# ---> 21 result = estimator.run(pubs=[pub]).result()
#      22 print(result[0].data.evs)
#      23 energy = result[0].data.evs[0]
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()
