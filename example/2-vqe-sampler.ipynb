# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_ibm_runtime import SamplerV2

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import AerSimulator

# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService(channel="ibm_quantum")
# backend = service.least_busy(operational=True, simulator=False)
backend = AerSimulator()
backend
# Out:
# AerSimulator('aer_simulator')

# %%
hamiltonian = SparsePauliOp.from_list(
    [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
)

# %%
ansatz = EfficientSU2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp")

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 16

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# #### Cost Function

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    # pub = (ansatz, [hamiltonian], [params])
    # result = estimator.run(pubs=[pub]).result()
    # energy = result[0].data.evs[0]


    # hamiltonian = SparsePauliOp.from_list(
    # [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)])
    shots = 10000
    energy = 0

    ansatz_1 = ansatz.copy()
    ansatz_1.sdg(0)
    ansatz_1.h(0)
    ansatz_1.cx(0,1)
    cr_1 = ClassicalRegister(1, name='my_c_1')
    ansatz_1.add_register(cr_1)
    ansatz_1.measure(1, cbit=cr_1)
    sampler = SamplerV2(backend=AerSimulator())
    job = sampler.run([(ansatz_1, [params], shots)])
    counts = job.result()[0].data.my_c_1.get_counts()
    total = sum(counts.values())
    probabilities = { state: count/total for state, count in counts.items() }
    probabilities['0'] = probabilities.get('0', 0.0)
    probabilities['1'] = probabilities.get('1', 0.0)
    exp_vals = (probabilities['0'])**2 - (probabilities['1'])**2
    # energy += exp_vals*0.3980
    energy += exp_vals
    

    ansatz_2 = ansatz.copy()
    ansatz_2.cx(0,1)
    cr_2 = ClassicalRegister(1, name='my_c_2')
    ansatz_2.add_register(cr_2)
    ansatz_2.measure(1, cbit=cr_2)
    sampler = SamplerV2(backend=AerSimulator())
    job = sampler.run([(ansatz_2, [params], shots)])
    counts = job.result()[0].data.my_c_2.get_counts()
    total = sum(counts.values())
    probabilities = { state: count/total for state, count in counts.items() }
    probabilities['0'] = probabilities.get('0', 0.0)
    probabilities['1'] = probabilities.get('1', 0.0)
    exp_vals = (probabilities['0'])**2 - (probabilities['1'])**2
    # energy += exp_vals*(-0.3980-0.0113)
    energy += exp_vals


    ansatz_3 = ansatz.copy()
    ansatz_3.h([0,1])
    ansatz_3.cx(0,1)
    cr_3 = ClassicalRegister(1, name='my_c_3')
    ansatz_3.add_register(cr_3)
    ansatz_3.measure(1, cbit=cr_3)
    sampler = SamplerV2(backend=AerSimulator())
    job = sampler.run([(ansatz_3, [params], shots)])
    counts = job.result()[0].data.my_c_3.get_counts()
    total = sum(counts.values())
    probabilities = { state: count/total for state, count in counts.items() }
    probabilities['0'] = probabilities.get('0', 0.0)
    probabilities['1'] = probabilities.get('1', 0.0)
    exp_vals = (probabilities['0'])**2 - (probabilities['1'])**2
    # energy += exp_vals*(0.1810)
    energy += exp_vals

    

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
np.random.seed(42)
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([2.35330497, 5.97351416, 4.59925358, 3.76148219, 0.98029403,
#        0.98014248, 0.3649501 , 5.44234523, 3.77691701, 4.44895122,
#        0.12933619, 6.09412333, 5.23039137, 1.33416598, 1.14243996,
#        1.15236452])

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 10000

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:157: UserWarning: Session is not supported in local testing mode or when using a simulator.
#   warnings.warn(
# Iters. done: 1 [Current cost: 0.7121999999999998]
# Iters. done: 2 [Current cost: -0.11800000000000005]
# Iters. done: 3 [Current cost: -0.6176]
# Iters. done: 4 [Current cost: -0.7128000000000001]
# Iters. done: 5 [Current cost: -1.0352000000000001]
# Iters. done: 6 [Current cost: -0.20559999999999995]
# Iters. done: 7 [Current cost: -1.0984]
# Iters. done: 8 [Current cost: -0.9300000000000002]
# Iters. done: 9 [Current cost: -0.05700000000000016]
# Iters. done: 10 [Current cost: -0.7808000000000002]
# Iters. done: 11 [Current cost: -0.6562]
# Iters. done: 12 [Current cost: -0.6006]
# Iters. done: 13 [Current cost: -1.1152]
# Iters. done: 14 [Current cost: -1.8486]
# Iters. done: 15 [Current cost: -0.9339999999999999]
# Iters. done: 16 [Current cost: -1.3017999999999998]
# Iters. done: 17 [Current cost: -1.7058]
# Iters. done: 18 [Current cost: -0.9736]
# Iters. done: 19 [Current cost: -1.7362]
# Iters. done: 20 [Current cost: -1.3181999999999998]
# Iters. done: 21 [Current cost: -1.8672]
# Iters. done: 22 [Current cost: -1.7704]
# Iters. done: 23 [Current cost: -2.0827999999999998]
# Iters. done: 24 [Current cost: -2.17]
# Iters. done: 25 [Current cost: -2.0856]
# Iters. done: 26 [Current cost: -2.2430000000000003]
# Iters. done: 27 [Current cost: -2.3179999999999996]
# Iters. done: 28 [Current cost: -2.2552000000000003]
# Iters. done: 29 [Current cost: -2.1822]
# Iters. done: 30 [Current cost: -2.257]
# Iters. done: 31 [Current cost: -2.2279999999999998]
# Iters. done: 32 [Current cost: -2.2074]
# Iters. done: 33 [Current cost: -1.9086]
# Iters. done: 34 [Current cost: -2.31]
# Iters. done: 35 [Current cost: -2.0886]
# Iters. done: 36 [Current cost: -2.2248]
# Iters. done: 37 [Current cost: -2.1634]
# Iters. done: 38 [Current cost: -2.2524]
# Iters. done: 39 [Current cost: -2.1486]
# Iters. done: 40 [Current cost: -2.2812]
# Iters. done: 41 [Current cost: -2.2922000000000002]
# Iters. done: 42 [Current cost: -2.3278]
# Iters. done: 43 [Current cost: -2.3242]
# Iters. done: 44 [Current cost: -2.2552000000000003]
# Iters. done: 45 [Current cost: -2.3052]
# Iters. done: 46 [Current cost: -2.3556]
# Iters. done: 47 [Current cost: -2.3246]
# Iters. done: 48 [Current cost: -2.3346]
# Iters. done: 49 [Current cost: -2.3396]
# Iters. done: 50 [Current cost: -2.3318000000000003]
# Iters. done: 51 [Current cost: -2.3662]
# Iters. done: 52 [Current cost: -2.3718]
# Iters. done: 53 [Current cost: -2.3884]
# Iters. done: 54 [Current cost: -2.3364]
# Iters. done: 55 [Current cost: -2.3904000000000005]
# Iters. done: 56 [Current cost: -2.3571999999999997]
# Iters. done: 57 [Current cost: -2.3726]
# Iters. done: 58 [Current cost: -2.3562000000000003]
# Iters. done: 59 [Current cost: -2.3777999999999997]
# Iters. done: 60 [Current cost: -2.3514]
# Iters. done: 61 [Current cost: -2.3815999999999997]
# Iters. done: 62 [Current cost: -2.3404]
# Iters. done: 63 [Current cost: -2.3418]
# Iters. done: 64 [Current cost: -2.3846]
# Iters. done: 65 [Current cost: -2.3608000000000002]
# Iters. done: 66 [Current cost: -2.3734]
# Iters. done: 67 [Current cost: -2.3484]
# Iters. done: 68 [Current cost: -2.3916]
# Iters. done: 69 [Current cost: -2.3819999999999997]
# Iters. done: 70 [Current cost: -2.3962]
# Iters. done: 71 [Current cost: -2.3682]
# Iters. done: 72 [Current cost: -2.3894]
# Iters. done: 73 [Current cost: -2.3954]
# Iters. done: 74 [Current cost: -2.3823999999999996]
# Iters. done: 75 [Current cost: -2.3958000000000004]
# Iters. done: 76 [Current cost: -2.3655999999999997]
# Iters. done: 77 [Current cost: -2.3846]
# Iters. done: 78 [Current cost: -2.3815999999999997]
# Iters. done: 79 [Current cost: -2.3822]
# Iters. done: 80 [Current cost: -2.3739999999999997]
# Iters. done: 81 [Current cost: -2.3853999999999997]
# Iters. done: 82 [Current cost: -2.3899999999999997]
# Iters. done: 83 [Current cost: -2.404]
# Iters. done: 84 [Current cost: -2.3912000000000004]
# Iters. done: 85 [Current cost: -2.3898]
# Iters. done: 86 [Current cost: -2.4059999999999997]
# Iters. done: 87 [Current cost: -2.3738]
# Iters. done: 88 [Current cost: -2.3716]
# Iters. done: 89 [Current cost: -2.3664]
# Iters. done: 90 [Current cost: -2.3772]
# Iters. done: 91 [Current cost: -2.4022]
# Iters. done: 92 [Current cost: -2.3436]
# Iters. done: 93 [Current cost: -2.3784]
# Iters. done: 94 [Current cost: -2.4067999999999996]
# Iters. done: 95 [Current cost: -2.3996]
# Iters. done: 96 [Current cost: -2.3644]
# Iters. done: 97 [Current cost: -2.3838]
# Iters. done: 98 [Current cost: -2.3882000000000003]
# Iters. done: 99 [Current cost: -2.363]
# Iters. done: 100 [Current cost: -2.3784]
# Iters. done: 101 [Current cost: -2.365]
# Iters. done: 102 [Current cost: -2.3906]
# Iters. done: 103 [Current cost: -2.3704]
# Iters. done: 104 [Current cost: -2.3704]
# Iters. done: 105 [Current cost: -2.3924000000000003]
# Iters. done: 106 [Current cost: -2.4044]
# Iters. done: 107 [Current cost: -2.3680000000000003]
# Iters. done: 108 [Current cost: -2.378]
# Iters. done: 109 [Current cost: -2.384]
# Iters. done: 110 [Current cost: -2.378]
# Iters. done: 111 [Current cost: -2.373]
# Iters. done: 112 [Current cost: -2.3898]
# Iters. done: 113 [Current cost: -2.387]
# Iters. done: 114 [Current cost: -2.3968]
# Iters. done: 115 [Current cost: -2.3636]
# Iters. done: 116 [Current cost: -2.3876]
# Iters. done: 117 [Current cost: -2.3814]
# Iters. done: 118 [Current cost: -2.3931999999999998]
# Iters. done: 119 [Current cost: -2.3578]
# Iters. done: 120 [Current cost: -2.3798]
# Iters. done: 121 [Current cost: -2.3742]
# Iters. done: 122 [Current cost: -2.3932]
# Iters. done: 123 [Current cost: -2.3884]
# Iters. done: 124 [Current cost: -2.3828]
# Iters. done: 125 [Current cost: -2.3818]
# Iters. done: 126 [Current cost: -2.3784]
# Iters. done: 127 [Current cost: -2.3948]
# Iters. done: 128 [Current cost: -2.3726000000000003]
# Iters. done: 129 [Current cost: -2.3928000000000003]
# Iters. done: 130 [Current cost: -2.387]
# Iters. done: 131 [Current cost: -2.3778]
# Iters. done: 132 [Current cost: -2.3764]
# Iters. done: 133 [Current cost: -2.3804]
# Iters. done: 134 [Current cost: -2.3857999999999997]
# Iters. done: 135 [Current cost: -2.3827999999999996]
# Iters. done: 136 [Current cost: -2.3811999999999998]
# Iters. done: 137 [Current cost: -2.3828]
# Iters. done: 138 [Current cost: -2.4052]
# Iters. done: 139 [Current cost: -2.382]
# Iters. done: 140 [Current cost: -2.3922]
# Iters. done: 141 [Current cost: -2.3754]
# Iters. done: 142 [Current cost: -2.4004000000000003]
# Iters. done: 143 [Current cost: -2.3762]
# Iters. done: 144 [Current cost: -2.3862]
# Iters. done: 145 [Current cost: -2.3731999999999998]
# Iters. done: 146 [Current cost: -2.3754]
# Iters. done: 147 [Current cost: -2.387]
# Iters. done: 148 [Current cost: -2.3896]
# Iters. done: 149 [Current cost: -2.402]
# Iters. done: 150 [Current cost: -2.3844000000000003]
# Iters. done: 151 [Current cost: -2.38]
# Iters. done: 152 [Current cost: -2.3806000000000003]
# Iters. done: 153 [Current cost: -2.3676000000000004]
# Iters. done: 154 [Current cost: -2.3838]
# Iters. done: 155 [Current cost: -2.3898]
# Iters. done: 156 [Current cost: -2.3908]
# Iters. done: 157 [Current cost: -2.3756000000000004]
# Iters. done: 158 [Current cost: -2.377]
# Iters. done: 159 [Current cost: -2.3776]
# Iters. done: 160 [Current cost: -2.3936]
# Iters. done: 161 [Current cost: -2.3728]
# Iters. done: 162 [Current cost: -2.3644]
# Iters. done: 163 [Current cost: -2.3842]
# Iters. done: 164 [Current cost: -2.3902]
# Iters. done: 165 [Current cost: -2.378]
# Iters. done: 166 [Current cost: -2.3886]
# Iters. done: 167 [Current cost: -2.3864]
# Iters. done: 168 [Current cost: -2.3794000000000004]
# Iters. done: 169 [Current cost: -2.3726000000000003]
# Iters. done: 170 [Current cost: -2.3758]

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()
