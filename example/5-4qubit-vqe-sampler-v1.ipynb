# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_ibm_runtime import SamplerV2

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import AerSimulator

# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService(channel="ibm_quantum")
# backend = service.least_busy(operational=True, simulator=False)
backend = AerSimulator()
backend
# Out:
# AerSimulator('aer_simulator')

# %%
hamiltonian = SparsePauliOp.from_list(
        [
        ('IIII', -0.09706627+0.j), ('ZIII',  0.17141283+0.j), ('IZII',  0.17141283+0.j),
        ('IIZI', -0.22343154+0.j), ('IIIZ', -0.22343154+0.j), ('ZZII',  0.16868898+0.j),
        ('ZIZI',  0.12062523+0.j), ('ZIIZ',  0.16592785+0.j), ('IZZI',  0.16592785+0.j),
        ('IZIZ',  0.12062523+0.j), ('IIZZ',  0.17441288+0.j),
        ('XXYY', -0.04530262+0.j),
        ('XYYX',  0.04530262+0.j),
        ('YXXY',  0.04530262+0.j),
        ('YYXX', -0.04530262+0.j)
    ]
)

# %%
ansatz = EfficientSU2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp")

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 32

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %%
ansatz_1 = ansatz.copy()
ansatz_1.sdg([0,1])
ansatz_1.h([0,1,2,3])
ansatz_1.cx(0,1)
ansatz_1.cx(1,2)
ansatz_1.cx(2,3)
cr_1 = ClassicalRegister(1, name='my_c_1')
ansatz_1.add_register(cr_1)

ansatz_1.measure(3, cbit=cr_1)
ansatz_1.draw(style='iqp', reverse_bits=False)

# %% [markdown]
# #### Cost Function

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    # pub = (ansatz, [hamiltonian], [params])
    # result = estimator.run(pubs=[pub]).result()
    # energy = result[0].data.evs[0]


    # hamiltonian = SparsePauliOp.from_list(
    # [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)])
    shots = 10000
    energy = 0

    ansatz_1 = ansatz.copy()
    ansatz_1.sdg([0,1])
    ansatz_1.h([0,1,2,3])
    ansatz_1.cx(0,1)
    ansatz_1.cx(1,2)
    ansatz_1.cx(2,3)
    cr_1 = ClassicalRegister(1, name='my_c_1')
    ansatz_1.add_register(cr_1)

    ansatz_1.measure(3, cbit=cr_1)
    sampler = SamplerV2(backend=AerSimulator())
    job = sampler.run([(ansatz_1, [params], shots)])
    counts = job.result()[0].data.my_c_1.get_counts()
    total = sum(counts.values())

    probabilities = { state: count/total for state, count in counts.items() }
    probabilities['0'] = probabilities.get('0', 0.0)
    probabilities['1'] = probabilities.get('1', 0.0)
    
    exp_vals = (probabilities['0'])**2 - (probabilities['1'])**2
    energy += exp_vals*-0.04530262
    

    # ansatz_2 = ansatz.copy()
    # ansatz_2.cx(0,1)
    # cr_2 = ClassicalRegister(1, name='my_c_2')
    # ansatz_2.add_register(cr_2)
    # ansatz_2.measure(1, cbit=cr_2)
    # sampler = SamplerV2(backend=AerSimulator())
    # job = sampler.run([(ansatz_2, [params], shots)])
    # counts = job.result()[0].data.my_c_2.get_counts()
    # total = sum(counts.values())
    # probabilities = { state: count/total for state, count in counts.items() }
    # probabilities['0'] = probabilities.get('0', 0.0)
    # probabilities['1'] = probabilities.get('1', 0.0)
    # exp_vals = (probabilities['0'])**2 - (probabilities['1'])**2
    # # energy += exp_vals*(-0.3980-0.0113)
    # energy += exp_vals


    # ansatz_3 = ansatz.copy()
    # ansatz_3.h([0,1])
    # ansatz_3.cx(0,1)
    # cr_3 = ClassicalRegister(1, name='my_c_3')
    # ansatz_3.add_register(cr_3)
    # ansatz_3.measure(1, cbit=cr_3)
    # sampler = SamplerV2(backend=AerSimulator())
    # job = sampler.run([(ansatz_3, [params], shots)])
    # counts = job.result()[0].data.my_c_3.get_counts()
    # total = sum(counts.values())
    # probabilities = { state: count/total for state, count in counts.items() }
    # probabilities['0'] = probabilities.get('0', 0.0)
    # probabilities['1'] = probabilities.get('1', 0.0)
    # exp_vals = (probabilities['0'])**2 - (probabilities['1'])**2
    # # energy += exp_vals*(0.1810)
    # energy += exp_vals

    

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
np.random.seed(42)
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([2.35330497, 5.97351416, 4.59925358, 3.76148219, 0.98029403,
#        0.98014248, 0.3649501 , 5.44234523, 3.77691701, 4.44895122,
#        0.12933619, 6.09412333, 5.23039137, 1.33416598, 1.14243996,
#        1.15236452, 1.91161039, 3.2971419 , 2.71399059, 1.82984665,
#        3.84438512, 0.87646578, 1.83559896, 2.30191935, 2.86557222,
#        4.93340606, 1.25458737, 3.23103027, 3.72225051, 0.29185655,
#        3.81731689, 1.07143467])

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 10000

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:157: UserWarning: Session is not supported in local testing mode or when using a simulator.
#   warnings.warn(
# Iters. done: 1 [Current cost: -0.024390930608]
# Iters. done: 2 [Current cost: -0.022995609911999997]
# Iters. done: 3 [Current cost: -0.019616034460000004]
# Iters. done: 4 [Current cost: -0.024472475324]
# Iters. done: 5 [Current cost: -0.01599182486]
# Iters. done: 6 [Current cost: -0.016617001016000003]
# Iters. done: 7 [Current cost: -0.024726169996000004]
# Iters. done: 8 [Current cost: -0.019371400312]
# Iters. done: 9 [Current cost: -0.016934119355999998]
# Iters. done: 10 [Current cost: -0.010646115700000004]
# Iters. done: 11 [Current cost: -0.016209277435999998]
# Iters. done: 12 [Current cost: -0.019697579176000003]
# Iters. done: 13 [Current cost: -0.009586034392]
# Iters. done: 14 [Current cost: -0.024128175412]
# Iters. done: 15 [Current cost: -0.024128175412]
# Iters. done: 16 [Current cost: -0.017042845644000004]
# Iters. done: 17 [Current cost: -0.017622719180000003]
# Iters. done: 18 [Current cost: -0.018700921536000004]
# Iters. done: 19 [Current cost: -0.022615067904000006]
# Iters. done: 20 [Current cost: -0.018528771580000002]
# Iters. done: 21 [Current cost: -0.017722384944]
# Iters. done: 22 [Current cost: -0.009413884435999999]
# Iters. done: 23 [Current cost: -0.02002375804]
# Iters. done: 24 [Current cost: -0.022270767992000007]
# Iters. done: 25 [Current cost: -0.012186404779999997]
# Iters. done: 26 [Current cost: -0.022814399432000004]
# Iters. done: 27 [Current cost: -0.023847299168]
# Iters. done: 28 [Current cost: -0.005173559204000001]
# Iters. done: 29 [Current cost: -0.020377118476]
# Iters. done: 30 [Current cost: -0.016499214204000003]
# Iters. done: 31 [Current cost: -0.006895058763999998]
# Iters. done: 32 [Current cost: -0.009649458060000001]
# Iters. done: 33 [Current cost: -0.013436757092]
# Iters. done: 34 [Current cost: -0.032083315484]
# Iters. done: 35 [Current cost: -0.024309385892]
# Iters. done: 36 [Current cost: -0.025940280212]
# Iters. done: 37 [Current cost: -0.027788627107999998]
# Iters. done: 38 [Current cost: -0.034946441068]
# Iters. done: 39 [Current cost: -0.030724236883999997]
# Iters. done: 40 [Current cost: -0.034547778012]
# Iters. done: 41 [Current cost: -0.032771915308000006]
# Iters. done: 42 [Current cost: -0.029573550336000003]
# Iters. done: 43 [Current cost: -0.031005113127999997]
# Iters. done: 44 [Current cost: -0.02858595322]
# Iters. done: 45 [Current cost: -0.03492832002]
# Iters. done: 46 [Current cost: -0.03529980150399999]
# Iters. done: 47 [Current cost: -0.033496757228]
# Iters. done: 48 [Current cost: -0.034330325436]
# Iters. done: 49 [Current cost: -0.033224941508000004]
# Iters. done: 50 [Current cost: -0.032554462732]
# Iters. done: 51 [Current cost: -0.0344299912]
# Iters. done: 52 [Current cost: -0.03539946726800001]
# Iters. done: 53 [Current cost: -0.032509160112]
# Iters. done: 54 [Current cost: -0.034475293819999996]
# Iters. done: 55 [Current cost: -0.033098094172]
# Iters. done: 56 [Current cost: -0.033750451900000006]
# Iters. done: 57 [Current cost: -0.03474710954]
# Iters. done: 58 [Current cost: -0.03288970212]
# Iters. done: 59 [Current cost: -0.03394978342800001]
# Iters. done: 60 [Current cost: -0.035326983076000004]
# Iters. done: 61 [Current cost: -0.03361454404]
# Iters. done: 62 [Current cost: -0.035317922552]
# Iters. done: 63 [Current cost: -0.034085691288]
# Iters. done: 64 [Current cost: -0.033007488932]
# Iters. done: 65 [Current cost: -0.03515483312]
# Iters. done: 66 [Current cost: -0.031159142036]
# Iters. done: 67 [Current cost: -0.034348446484]
# Iters. done: 68 [Current cost: -0.032264525964]
# Iters. done: 69 [Current cost: -0.035182014692]
# Iters. done: 70 [Current cost: -0.034484354344000004]
# Iters. done: 71 [Current cost: -0.036414245956000006]
# Iters. done: 72 [Current cost: -0.035807190848]
# Iters. done: 73 [Current cost: -0.03846192438]
# Iters. done: 74 [Current cost: -0.037175329972]
# Iters. done: 75 [Current cost: -0.038063261324]
# Iters. done: 76 [Current cost: -0.036731364296]
# Iters. done: 77 [Current cost: -0.03824447180400001]
# Iters. done: 78 [Current cost: -0.038217290232]
# Iters. done: 79 [Current cost: -0.03769177984]
# Iters. done: 80 [Current cost: -0.038996495296]
# Iters. done: 81 [Current cost: -0.038226350756000005]
# Iters. done: 82 [Current cost: -0.03846192438]
# Iters. done: 83 [Current cost: -0.038806224292]
# Iters. done: 84 [Current cost: -0.039041797915999994]
# Iters. done: 85 [Current cost: -0.037900171892000005]
# Iters. done: 86 [Current cost: -0.038570650668]
# Iters. done: 87 [Current cost: -0.038670316431999995]
# Iters. done: 88 [Current cost: -0.038561590144]
# Iters. done: 89 [Current cost: -0.038842466388]
# Iters. done: 90 [Current cost: -0.03905085844000001]
# Iters. done: 91 [Current cost: -0.039213947872]
# Iters. done: 92 [Current cost: -0.03973039774]
# Iters. done: 93 [Current cost: -0.039014616344]
# Iters. done: 94 [Current cost: -0.03978476088400001]
# Iters. done: 95 [Current cost: -0.038996495296]
# Iters. done: 96 [Current cost: -0.039105221584]
# Iters. done: 97 [Current cost: -0.040862963239999994]
# Iters. done: 98 [Current cost: -0.039241129444]
# Iters. done: 99 [Current cost: -0.040446179136]
# Iters. done: 100 [Current cost: -0.039848184551999996]
# Iters. done: 101 [Current cost: -0.04063645014]
# Iters. done: 102 [Current cost: -0.040418997564000005]
# Iters. done: 103 [Current cost: -0.041252565772000004]
# Iters. done: 104 [Current cost: -0.041297868392]
# Iters. done: 105 [Current cost: -0.04113477896]
# Iters. done: 106 [Current cost: -0.04004751608]
# Iters. done: 107 [Current cost: -0.041261626296000005]
# Iters. done: 108 [Current cost: -0.04043711861200001]
# Iters. done: 109 [Current cost: -0.041306928916]
# Iters. done: 110 [Current cost: -0.041669349875999996]
# Iters. done: 111 [Current cost: -0.04080860009600001]
# Iters. done: 112 [Current cost: -0.041750894592]
# Iters. done: 113 [Current cost: -0.041968347168]
# Iters. done: 114 [Current cost: -0.041723713020000004]
# Iters. done: 115 [Current cost: -0.041633107780000005]
# Iters. done: 116 [Current cost: -0.041687470924]
# Iters. done: 117 [Current cost: -0.041832439308]
# Iters. done: 118 [Current cost: -0.041234444723999994]
# Iters. done: 119 [Current cost: -0.042031770836]
# Iters. done: 120 [Current cost: -0.041895862976]
# Iters. done: 121 [Current cost: -0.041832439308]
# Iters. done: 122 [Current cost: -0.042122376076]
# Iters. done: 123 [Current cost: -0.041642168304]
# Iters. done: 124 [Current cost: -0.042684128564]
# Iters. done: 125 [Current cost: -0.042330768128]
# Iters. done: 126 [Current cost: -0.041533442016000004]
# Iters. done: 127 [Current cost: -0.042774733804]
# Iters. done: 128 [Current cost: -0.043227760004]
# Iters. done: 129 [Current cost: -0.043191517908]
# Iters. done: 130 [Current cost: -0.040790479048000004]
# Iters. done: 131 [Current cost: -0.042457615464]
# Iters. done: 132 [Current cost: -0.043300244196]
# Iters. done: 133 [Current cost: -0.042647886468]
# Iters. done: 134 [Current cost: -0.04297406533200001]
# Iters. done: 135 [Current cost: -0.043354607340000004]
# Iters. done: 136 [Current cost: -0.042611644372000004]
# Iters. done: 137 [Current cost: -0.043109973192]
# Iters. done: 138 [Current cost: -0.043282123148]
# Iters. done: 139 [Current cost: -0.043173396860000005]
# Iters. done: 140 [Current cost: -0.043408970484]
# Iters. done: 141 [Current cost: -0.04262976542000001]
# Iters. done: 142 [Current cost: -0.042521039132000005]
# Iters. done: 143 [Current cost: -0.043245881052]
# Iters. done: 144 [Current cost: -0.042801915376000005]
# Iters. done: 145 [Current cost: -0.042240162888]
# Iters. done: 146 [Current cost: -0.043291183672]
# Iters. done: 147 [Current cost: -0.043427091531999994]
# Iters. done: 148 [Current cost: -0.04285627852]
# Iters. done: 149 [Current cost: -0.043472394152]
# Iters. done: 150 [Current cost: -0.04380763354000001]
# Iters. done: 151 [Current cost: -0.043191517908]
# Iters. done: 152 [Current cost: -0.042937823236]
# Iters. done: 153 [Current cost: -0.043481454676]
# Iters. done: 154 [Current cost: -0.042874399567999995]
# Iters. done: 155 [Current cost: -0.043037489]
# Iters. done: 156 [Current cost: -0.043481454676]
# Iters. done: 157 [Current cost: -0.043109973192]
# Iters. done: 158 [Current cost: -0.042339828652000006]
# Iters. done: 159 [Current cost: -0.043771391443999996]
# Iters. done: 160 [Current cost: -0.042892520616000004]
# Iters. done: 161 [Current cost: -0.043408970484]
# Iters. done: 162 [Current cost: -0.042394191796]
# Iters. done: 163 [Current cost: -0.043408970484]
# Iters. done: 164 [Current cost: -0.043463333628000006]
# Iters. done: 165 [Current cost: -0.04339990996]
# Iters. done: 166 [Current cost: -0.043662665156]
# Iters. done: 167 [Current cost: -0.04344521258]
# Iters. done: 168 [Current cost: -0.042910641664]
# Iters. done: 169 [Current cost: -0.043481454676]
# Iters. done: 170 [Current cost: -0.043499575724]
# Iters. done: 171 [Current cost: -0.043572059916]
# Iters. done: 172 [Current cost: -0.04330930472]
# Iters. done: 173 [Current cost: -0.043264002100000004]
# Iters. done: 174 [Current cost: -0.043173396860000005]
# Iters. done: 175 [Current cost: -0.04339990996]
# Iters. done: 176 [Current cost: -0.043572059916]
# Iters. done: 177 [Current cost: -0.043780451968]
# Iters. done: 178 [Current cost: -0.04362642306]
# Iters. done: 179 [Current cost: -0.043010307428]
# Iters. done: 180 [Current cost: -0.04330930472]
# Iters. done: 181 [Current cost: -0.043689846728]
# Iters. done: 182 [Current cost: -0.04358112044]
# Iters. done: 183 [Current cost: -0.04379857301600001]
# Iters. done: 184 [Current cost: -0.043517696772]
# Iters. done: 185 [Current cost: -0.043816694064]
# Iters. done: 186 [Current cost: -0.043680786204]
# Iters. done: 187 [Current cost: -0.043553938868000006]
# Iters. done: 188 [Current cost: -0.043599241488]
# Iters. done: 189 [Current cost: -0.043599241488]
# Iters. done: 190 [Current cost: -0.04362642306]
# Iters. done: 191 [Current cost: -0.04353581782]
# Iters. done: 192 [Current cost: -0.043880117732]
# Iters. done: 193 [Current cost: -0.043871057208]
# Iters. done: 194 [Current cost: -0.043771391443999996]
# Iters. done: 195 [Current cost: -0.044052267687999996]
# Iters. done: 196 [Current cost: -0.04380763354000001]
# Iters. done: 197 [Current cost: -0.043952601924]
# Iters. done: 198 [Current cost: -0.043925420352000005]
# Iters. done: 199 [Current cost: -0.043698907252]
# Iters. done: 200 [Current cost: -0.043735149348000005]
# Iters. done: 201 [Current cost: -0.043644544108000005]
# Iters. done: 202 [Current cost: -0.043771391443999996]
# Iters. done: 203 [Current cost: -0.043517696772]
# Iters. done: 204 [Current cost: -0.043916359828000004]
# Iters. done: 205 [Current cost: -0.043907299304]
# Iters. done: 206 [Current cost: -0.043979783496000006]
# Iters. done: 207 [Current cost: -0.043726088824]
# Iters. done: 208 [Current cost: -0.043907299304]
# Iters. done: 209 [Current cost: -0.04362642306]
# Iters. done: 210 [Current cost: -0.043861996684]
# Iters. done: 211 [Current cost: -0.043916359828000004]
# Iters. done: 212 [Current cost: -0.043753270396]
# Iters. done: 213 [Current cost: -0.04362642306]
# Iters. done: 214 [Current cost: -0.044151933452]
# Iters. done: 215 [Current cost: -0.044043207164]
# Iters. done: 216 [Current cost: -0.04403414664]
# Iters. done: 217 [Current cost: -0.043970722972]
# Iters. done: 218 [Current cost: -0.043979783496000006]
# Iters. done: 219 [Current cost: -0.043907299304]
# Iters. done: 220 [Current cost: -0.04398884402000001]
# Iters. done: 221 [Current cost: -0.04389823878000001]
# Iters. done: 222 [Current cost: -0.043907299304]
# Iters. done: 223 [Current cost: -0.044025086116]
# Iters. done: 224 [Current cost: -0.044043207164]
# Iters. done: 225 [Current cost: -0.043934480876]
# Iters. done: 226 [Current cost: -0.043572059916]
# Iters. done: 227 [Current cost: -0.043780451968]
# Iters. done: 228 [Current cost: -0.044061328212]
# Iters. done: 229 [Current cost: -0.043952601924]
# Iters. done: 230 [Current cost: -0.043843875636]
# Iters. done: 231 [Current cost: -0.044043207164]
# Iters. done: 232 [Current cost: -0.043834815112000006]
# Iters. done: 233 [Current cost: -0.043871057208]
# Iters. done: 234 [Current cost: -0.043753270396]
# Iters. done: 235 [Current cost: -0.04421535712]
# Iters. done: 236 [Current cost: -0.043961662448]
# Iters. done: 237 [Current cost: -0.044224417644]
# Iters. done: 238 [Current cost: -0.044115691356]
# Iters. done: 239 [Current cost: -0.044133812404]
# Iters. done: 240 [Current cost: -0.0439435414]
# Iters. done: 241 [Current cost: -0.044097570308]
# Iters. done: 242 [Current cost: -0.044070388736000006]
# Iters. done: 243 [Current cost: -0.044179115024]
# Iters. done: 244 [Current cost: -0.043997904544]
# Iters. done: 245 [Current cost: -0.043970722972]
# Iters. done: 246 [Current cost: -0.044061328212]
# Iters. done: 247 [Current cost: -0.04398884402000001]
# Iters. done: 248 [Current cost: -0.044188175548]
# Iters. done: 249 [Current cost: -0.04421535712]
# Iters. done: 250 [Current cost: -0.044097570308]
# Iters. done: 251 [Current cost: -0.043997904544]
# Iters. done: 252 [Current cost: -0.044106630832000004]
# Iters. done: 253 [Current cost: -0.044070388736000006]
# Iters. done: 254 [Current cost: -0.044188175548]
# Iters. done: 255 [Current cost: -0.044061328212]
# Iters. done: 256 [Current cost: -0.044070388736000006]
# Iters. done: 257 [Current cost: -0.04398884402000001]
# Iters. done: 258 [Current cost: -0.044197236072000004]
# Iters. done: 259 [Current cost: -0.044206296596]
# Iters. done: 260 [Current cost: -0.04421535712]
# Iters. done: 261 [Current cost: -0.0439435414]
# Iters. done: 262 [Current cost: -0.044061328212]
# Iters. done: 263 [Current cost: -0.044115691356]
# Iters. done: 264 [Current cost: -0.04421535712]
# Iters. done: 265 [Current cost: -0.04398884402000001]
# Iters. done: 266 [Current cost: -0.044061328212]
# Iters. done: 267 [Current cost: -0.044133812404]
# Iters. done: 268 [Current cost: -0.044061328212]
# Iters. done: 269 [Current cost: -0.04421535712]
# Iters. done: 270 [Current cost: -0.043925420352000005]
# Iters. done: 271 [Current cost: -0.044106630832000004]
# Iters. done: 272 [Current cost: -0.044160993976000006]
# Iters. done: 273 [Current cost: -0.044133812404]
# Iters. done: 274 [Current cost: -0.04407944926000001]
# Iters. done: 275 [Current cost: -0.044043207164]
# Iters. done: 276 [Current cost: -0.04407944926000001]
# Iters. done: 277 [Current cost: -0.04407944926000001]
# Iters. done: 278 [Current cost: -0.044106630832000004]
# Iters. done: 279 [Current cost: -0.044251599216]
# Iters. done: 280 [Current cost: -0.04407944926000001]
# Iters. done: 281 [Current cost: -0.044006965068000004]
# Iters. done: 282 [Current cost: -0.044151933452]
# Iters. done: 283 [Current cost: -0.044016025592000005]
# Iters. done: 284 [Current cost: -0.044097570308]
# Iters. done: 285 [Current cost: -0.04426972026400001]
# Iters. done: 286 [Current cost: -0.044106630832000004]
# Iters. done: 287 [Current cost: -0.04403414664]
# Iters. done: 288 [Current cost: -0.044151933452]
# Iters. done: 289 [Current cost: -0.043952601924]
# Iters. done: 290 [Current cost: -0.043871057208]
# Iters. done: 291 [Current cost: -0.04412475188]
# Iters. done: 292 [Current cost: -0.044233478167999996]
# Iters. done: 293 [Current cost: -0.044006965068000004]
# Iters. done: 294 [Current cost: -0.043916359828000004]
# Iters. done: 295 [Current cost: -0.04388917825600001]
# Iters. done: 296 [Current cost: -0.04398884402000001]
# Iters. done: 297 [Current cost: -0.04407944926000001]
# Iters. done: 298 [Current cost: -0.04403414664]
# Iters. done: 299 [Current cost: -0.04398884402000001]
# Iters. done: 300 [Current cost: -0.044088509784]
# Iters. done: 301 [Current cost: -0.044233478167999996]
# Iters. done: 302 [Current cost: -0.043952601924]
# Iters. done: 303 [Current cost: -0.043970722972]
# Iters. done: 304 [Current cost: -0.044287841312000004]
# Iters. done: 305 [Current cost: -0.043753270396]
# Iters. done: 306 [Current cost: -0.04398884402000001]
# Iters. done: 307 [Current cost: -0.044016025592000005]
# Iters. done: 308 [Current cost: -0.04412475188]
# Iters. done: 309 [Current cost: -0.044088509784]
# Iters. done: 310 [Current cost: -0.044115691356]
# Iters. done: 311 [Current cost: -0.04417005450000001]
# Iters. done: 312 [Current cost: -0.044061328212]
# Iters. done: 313 [Current cost: -0.044188175548]
# Iters. done: 314 [Current cost: -0.044142872927999996]
# Iters. done: 315 [Current cost: -0.044160993976000006]
# Iters. done: 316 [Current cost: -0.043916359828000004]
# Iters. done: 317 [Current cost: -0.044133812404]
# Iters. done: 318 [Current cost: -0.04407944926000001]
# Iters. done: 319 [Current cost: -0.044224417644]
# Iters. done: 320 [Current cost: -0.04398884402000001]
# Iters. done: 321 [Current cost: -0.044097570308]
# Iters. done: 322 [Current cost: -0.04398884402000001]
# Iters. done: 323 [Current cost: -0.044142872927999996]
# Iters. done: 324 [Current cost: -0.043925420352000005]
# Iters. done: 325 [Current cost: -0.043997904544]
# Iters. done: 326 [Current cost: -0.044097570308]
# Iters. done: 327 [Current cost: -0.043861996684]
# Iters. done: 328 [Current cost: -0.044052267687999996]
# Iters. done: 329 [Current cost: -0.044006965068000004]
# Iters. done: 330 [Current cost: -0.044016025592000005]
# Iters. done: 331 [Current cost: -0.044016025592000005]
# Iters. done: 332 [Current cost: -0.044106630832000004]
# Iters. done: 333 [Current cost: -0.044106630832000004]
# Iters. done: 334 [Current cost: -0.043934480876]
# Iters. done: 335 [Current cost: -0.043979783496000006]
# Iters. done: 336 [Current cost: -0.043979783496000006]
# Iters. done: 337 [Current cost: -0.043907299304]
# Iters. done: 338 [Current cost: -0.043925420352000005]
# Iters. done: 339 [Current cost: -0.044188175548]
# Iters. done: 340 [Current cost: -0.044197236072000004]
# Iters. done: 341 [Current cost: -0.044070388736000006]
# Iters. done: 342 [Current cost: -0.043970722972]
# Iters. done: 343 [Current cost: -0.04426972026400001]
# Iters. done: 344 [Current cost: -0.043970722972]
# Iters. done: 345 [Current cost: -0.044016025592000005]
# Iters. done: 346 [Current cost: -0.04398884402000001]
# Iters. done: 347 [Current cost: -0.044197236072000004]
# Iters. done: 348 [Current cost: -0.043952601924]
# Iters. done: 349 [Current cost: -0.043952601924]
# Iters. done: 350 [Current cost: -0.04417005450000001]
# Iters. done: 351 [Current cost: -0.044233478167999996]
# Iters. done: 352 [Current cost: -0.044088509784]
# Iters. done: 353 [Current cost: -0.044088509784]
# Iters. done: 354 [Current cost: -0.04417005450000001]
# Iters. done: 355 [Current cost: -0.043834815112000006]
# Iters. done: 356 [Current cost: -0.043961662448]
# Iters. done: 357 [Current cost: -0.04412475188]
# Iters. done: 358 [Current cost: -0.044133812404]
# Iters. done: 359 [Current cost: -0.044016025592000005]
# Iters. done: 360 [Current cost: -0.044206296596]
# Iters. done: 361 [Current cost: -0.043997904544]
# Iters. done: 362 [Current cost: -0.044052267687999996]
# Iters. done: 363 [Current cost: -0.044179115024]
# Iters. done: 364 [Current cost: -0.044088509784]
# Iters. done: 365 [Current cost: -0.04412475188]
# Iters. done: 366 [Current cost: -0.043916359828000004]
# Iters. done: 367 [Current cost: -0.04412475188]
# Iters. done: 368 [Current cost: -0.044052267687999996]
# Iters. done: 369 [Current cost: -0.044025086116]
# Iters. done: 370 [Current cost: -0.043979783496000006]
# Iters. done: 371 [Current cost: -0.044052267687999996]
# Iters. done: 372 [Current cost: -0.044142872927999996]
# Iters. done: 373 [Current cost: -0.044016025592000005]
# Iters. done: 374 [Current cost: -0.044106630832000004]
# Iters. done: 375 [Current cost: -0.044142872927999996]
# Iters. done: 376 [Current cost: -0.044142872927999996]
# Iters. done: 377 [Current cost: -0.044188175548]
# Iters. done: 378 [Current cost: -0.04407944926000001]
# Iters. done: 379 [Current cost: -0.044260659740000007]
# Iters. done: 380 [Current cost: -0.044133812404]
# Iters. done: 381 [Current cost: -0.044133812404]
# Iters. done: 382 [Current cost: -0.04403414664]
# Iters. done: 383 [Current cost: -0.04398884402000001]
# Iters. done: 384 [Current cost: -0.043997904544]
# Iters. done: 385 [Current cost: -0.044188175548]
# Iters. done: 386 [Current cost: -0.04385293616]
# Iters. done: 387 [Current cost: -0.044296901836000005]
# Iters. done: 388 [Current cost: -0.044025086116]
# Iters. done: 389 [Current cost: -0.044070388736000006]
# Iters. done: 390 [Current cost: -0.043979783496000006]
# Iters. done: 391 [Current cost: -0.044052267687999996]
# Iters. done: 392 [Current cost: -0.044070388736000006]
# Iters. done: 393 [Current cost: -0.044043207164]
# Iters. done: 394 [Current cost: -0.044088509784]
# Iters. done: 395 [Current cost: -0.04407944926000001]
# Iters. done: 396 [Current cost: -0.044097570308]
# Iters. done: 397 [Current cost: -0.04412475188]

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
ax.set_ylim(-0.05,0)
plt.draw()
