# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_ibm_runtime import SamplerV2

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import AerSimulator

# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService(channel="ibm_quantum")
# backend = service.least_busy(operational=True, simulator=False)
backend = AerSimulator()
backend
# Out:
# AerSimulator('aer_simulator')

# %%
hamiltonian = SparsePauliOp.from_list(
    [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
)

# %%
ansatz = EfficientSU2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp")

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 16

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# #### Cost Function

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def get_probability_distribution(counts, NUM_SHOTS):

    for k in {'00', '01', '10', '11'}:
        if k not in counts.keys():
            counts[k] = 0
    sorted_counts = sorted(counts.items())

    output_distr = [ v[1] / NUM_SHOTS for v in sorted_counts]
    if len(output_distr) == 1:
        output_distr.append(1-output_distr[0])
    return output_distr

def cost_func(params, ansatz, hamiltonian):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    # pub = (ansatz, [hamiltonian], [params])
    # result = estimator.run(pubs=[pub]).result()
    # energy = result[0].data.evs[0]


    # hamiltonian = SparsePauliOp.from_list(
    # [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)])

    shots = 10000
    energy = 0

    # CLIQUE 1: YZ
    ansatz_1 = ansatz.copy()
    ansatz_1.sdg(0)
    ansatz_1.h(0)
    ansatz_1.measure_all()

    sampler = SamplerV2(backend=AerSimulator())
    job = sampler.run([(ansatz_1, [params], shots)])
    counts = job.result()[0].data.meas.get_counts()
    output_distribution = get_probability_distribution(counts, sum(counts.values()))
    eigenvalues_YZ = np.kron([1,-1], [1,-1])

    expectation_values_YZ = np.dot(eigenvalues_YZ, output_distribution)
    energy += expectation_values_YZ*0.3980
    

    # CLIQUE 2: ZI, ZZ
    ansatz_2 = ansatz.copy()
    ansatz_2.measure_all()

    sampler = SamplerV2(backend=AerSimulator())
    job = sampler.run([(ansatz_2, [params], shots)])
    counts = job.result()[0].data.meas.get_counts()
    # print("COUNTS:", counts)
    output_distribution = get_probability_distribution(counts, sum(counts.values()))
    
    eigenvalues_ZI = np.kron([1,-1], [1,1])
    eigenvalues_ZZ = np.kron([1,1], [1,-1])

    expectation_values_ZI = np.dot(eigenvalues_ZI, output_distribution)
    expectation_values_ZZ = np.dot(eigenvalues_ZZ, output_distribution)

    energy += expectation_values_ZI*-0.3980 + expectation_values_ZZ*-0.0113


    # CLIQUE 3: XX
    ansatz_3 = ansatz.copy()
    ansatz_3.h([0,1])
    ansatz_3.measure_all()

    sampler = SamplerV2(backend=AerSimulator())
    job = sampler.run([(ansatz_3, [params], shots)])
    counts = job.result()[0].data.meas.get_counts()
    # print("COUNTS:", counts)
    output_distribution = get_probability_distribution(counts, sum(counts.values()))
    
    eigenvalues_XX = np.kron([1,-1], [1,-1])
    expectation_values_XX = np.dot(eigenvalues_XX, output_distribution)

    energy += expectation_values_XX*0.1810
    
    

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
np.random.seed(42)
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([2.35330497, 5.97351416, 4.59925358, 3.76148219, 0.98029403,
#        0.98014248, 0.3649501 , 5.44234523, 3.77691701, 4.44895122,
#        0.12933619, 6.09412333, 5.23039137, 1.33416598, 1.14243996,
#        1.15236452])

# %%
with Session(backend=backend) as session:
    # estimator = Estimator(session=session)
    # estimator.options.default_shots = 10000

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa),
        method="cobyla",
    )
# Out:
# Iters. done: 1 [Current cost: 0.15698628000000003]
# Iters. done: 2 [Current cost: -0.2285643]
# Iters. done: 3 [Current cost: -0.13043651999999997]
# Iters. done: 4 [Current cost: -0.12374456000000003]
# Iters. done: 5 [Current cost: -0.08844316000000002]
# Iters. done: 6 [Current cost: 0.028423560000000014]
# Iters. done: 7 [Current cost: 0.16738462]
# Iters. done: 8 [Current cost: -0.3107787]
# Iters. done: 9 [Current cost: -0.10208000000000005]
# Iters. done: 10 [Current cost: -0.14724937999999999]
# Iters. done: 11 [Current cost: -0.6606799400000001]
# Iters. done: 12 [Current cost: -0.6165034]
# Iters. done: 13 [Current cost: -0.42402384000000004]
# Iters. done: 14 [Current cost: -0.47609512]
# Iters. done: 15 [Current cost: -0.3813642200000001]
# Iters. done: 16 [Current cost: -0.41853517999999995]
# Iters. done: 17 [Current cost: -0.75727034]
# Iters. done: 18 [Current cost: -0.70686126]
# Iters. done: 19 [Current cost: -0.6993794]
# Iters. done: 20 [Current cost: -0.7433779600000001]
# Iters. done: 21 [Current cost: -0.7305637000000001]
# Iters. done: 22 [Current cost: -0.7726077800000001]
# Iters. done: 23 [Current cost: -0.68430688]
# Iters. done: 24 [Current cost: -0.7617052400000001]
# Iters. done: 25 [Current cost: -0.71927264]
# Iters. done: 26 [Current cost: -0.7572217800000001]
# Iters. done: 27 [Current cost: -0.6809301599999998]
# Iters. done: 28 [Current cost: -0.7644327399999999]
# Iters. done: 29 [Current cost: -0.6525672200000001]
# Iters. done: 30 [Current cost: -0.7822110800000001]
# Iters. done: 31 [Current cost: -0.7120918800000001]
# Iters. done: 32 [Current cost: -0.8032091600000001]
# Iters. done: 33 [Current cost: -0.7192050000000001]
# Iters. done: 34 [Current cost: -0.7610897400000001]
# Iters. done: 35 [Current cost: -0.8044154000000001]
# Iters. done: 36 [Current cost: -0.7751530000000002]
# Iters. done: 37 [Current cost: -0.7387974800000001]
# Iters. done: 38 [Current cost: -0.7835199799999999]
# Iters. done: 39 [Current cost: -0.8007456000000001]
# Iters. done: 40 [Current cost: -0.8077881800000001]
# Iters. done: 41 [Current cost: -0.7888602600000001]
# Iters. done: 42 [Current cost: -0.8194072000000001]
# Iters. done: 43 [Current cost: -0.81956766]
# Iters. done: 44 [Current cost: -0.83076092]
# Iters. done: 45 [Current cost: -0.82785062]
# Iters. done: 46 [Current cost: -0.8153672799999999]
# Iters. done: 47 [Current cost: -0.8189854200000001]
# Iters. done: 48 [Current cost: -0.8107277]
# Iters. done: 49 [Current cost: -0.82302852]
# Iters. done: 50 [Current cost: -0.8132298600000001]
# Iters. done: 51 [Current cost: -0.82030022]
# Iters. done: 52 [Current cost: -0.7986678600000001]
# Iters. done: 53 [Current cost: -0.8222270799999999]
# Iters. done: 54 [Current cost: -0.8142637800000001]
# Iters. done: 55 [Current cost: -0.82447218]
# Iters. done: 56 [Current cost: -0.81310108]
# Iters. done: 57 [Current cost: -0.82456412]
# Iters. done: 58 [Current cost: -0.8206131799999999]
# Iters. done: 59 [Current cost: -0.82837352]
# Iters. done: 60 [Current cost: -0.82080806]
# Iters. done: 61 [Current cost: -0.8275096200000001]
# Iters. done: 62 [Current cost: -0.8280892000000001]
# Iters. done: 63 [Current cost: -0.82451296]
# Iters. done: 64 [Current cost: -0.8223788200000001]
# Iters. done: 65 [Current cost: -0.8252521400000001]
# Iters. done: 66 [Current cost: -0.8216758800000001]
# Iters. done: 67 [Current cost: -0.81976928]
# Iters. done: 68 [Current cost: -0.82401788]
# Iters. done: 69 [Current cost: -0.8246093200000001]
# Iters. done: 70 [Current cost: -0.8236895599999999]
# Iters. done: 71 [Current cost: -0.8241118]
# Iters. done: 72 [Current cost: -0.82267036]
# Iters. done: 73 [Current cost: -0.81632412]
# Iters. done: 74 [Current cost: -0.82862486]
# Iters. done: 75 [Current cost: -0.8233908600000001]
# Iters. done: 76 [Current cost: -0.8246904999999999]
# Iters. done: 77 [Current cost: -0.8209295200000001]
# Iters. done: 78 [Current cost: -0.82549056]
# Iters. done: 79 [Current cost: -0.82439808]
# Iters. done: 80 [Current cost: -0.82109558]
# Iters. done: 81 [Current cost: -0.8213378]
# Iters. done: 82 [Current cost: -0.82492794]
# Iters. done: 83 [Current cost: -0.8235225000000002]
# Iters. done: 84 [Current cost: -0.8229810200000001]
# Iters. done: 85 [Current cost: -0.82702566]
# Iters. done: 86 [Current cost: -0.8282351000000001]
# Iters. done: 87 [Current cost: -0.8241534399999999]
# Iters. done: 88 [Current cost: -0.82715846]
# Iters. done: 89 [Current cost: -0.8242853]
# Iters. done: 90 [Current cost: -0.8233889000000001]
# Iters. done: 91 [Current cost: -0.82551988]
# Iters. done: 92 [Current cost: -0.8181096]
# Iters. done: 93 [Current cost: -0.8237511800000001]
# Iters. done: 94 [Current cost: -0.82122578]
# Iters. done: 95 [Current cost: -0.8281048400000002]
# Iters. done: 96 [Current cost: -0.8244355999999999]
# Iters. done: 97 [Current cost: -0.8217329200000001]
# Iters. done: 98 [Current cost: -0.8239344200000001]
# Iters. done: 99 [Current cost: -0.82154604]
# Iters. done: 100 [Current cost: -0.82523232]
# Iters. done: 101 [Current cost: -0.82449416]
# Iters. done: 102 [Current cost: -0.82359328]
# Iters. done: 103 [Current cost: -0.8234477]
# Iters. done: 104 [Current cost: -0.8214915599999999]
# Iters. done: 105 [Current cost: -0.8245926199999999]
# Iters. done: 106 [Current cost: -0.8174908000000001]
# Iters. done: 107 [Current cost: -0.8271448]
# Iters. done: 108 [Current cost: -0.82330338]
# Iters. done: 109 [Current cost: -0.82574308]
# Iters. done: 110 [Current cost: -0.82516684]
# Iters. done: 111 [Current cost: -0.8242272200000001]
# Iters. done: 112 [Current cost: -0.8223309799999999]
# Iters. done: 113 [Current cost: -0.8276191800000001]
# Iters. done: 114 [Current cost: -0.82345536]
# Iters. done: 115 [Current cost: -0.8210994600000001]
# Iters. done: 116 [Current cost: -0.8205884800000001]
# Iters. done: 117 [Current cost: -0.8262594800000002]
# Iters. done: 118 [Current cost: -0.82653564]
# Iters. done: 119 [Current cost: -0.82562314]
# Iters. done: 120 [Current cost: -0.82439994]
# Iters. done: 121 [Current cost: -0.8247698799999998]
# Iters. done: 122 [Current cost: -0.8236679400000001]
# Iters. done: 123 [Current cost: -0.8257448]
# Iters. done: 124 [Current cost: -0.8202081800000001]
# Iters. done: 125 [Current cost: -0.82885734]
# Iters. done: 126 [Current cost: -0.81791316]
# Iters. done: 127 [Current cost: -0.82052336]
# Iters. done: 128 [Current cost: -0.8223809]
# Iters. done: 129 [Current cost: -0.82224276]
# Iters. done: 130 [Current cost: -0.82268236]
# Iters. done: 131 [Current cost: -0.8217519200000001]
# Iters. done: 132 [Current cost: -0.82444516]
# Iters. done: 133 [Current cost: -0.8265736000000001]
# Iters. done: 134 [Current cost: -0.8271902400000001]
# Iters. done: 135 [Current cost: -0.8185872000000001]
# Iters. done: 136 [Current cost: -0.8211546399999999]
# Iters. done: 137 [Current cost: -0.8231460399999999]
# Iters. done: 138 [Current cost: -0.8242351600000002]
# Iters. done: 139 [Current cost: -0.8223390799999999]
# Iters. done: 140 [Current cost: -0.824595]
# Iters. done: 141 [Current cost: -0.8228871400000001]
# Iters. done: 142 [Current cost: -0.8201369599999999]
# Iters. done: 143 [Current cost: -0.82060664]

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()
