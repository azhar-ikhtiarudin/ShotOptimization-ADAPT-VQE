# %%
# %load_ext autoreload
# %autoreload 2

sys.path.append('/home/azhar04/project/1. dev/quantum-dev/ShotOptimized-ADAPT-VQE/')
print(sys.executable)

import sys
import json
from visualization.visualize import plotErrorToAdaptIterations, plotErrorToAdaptAndOptimizerIterations, plotErrorToCumulativeShots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/azhar04/anaconda3/envs/qiskit-1-2/bin/python

# %%
filename = '../data/data_H3_N=10000000_k=1000_Nexp=10_T=090125_214351.json'

with open(filename, 'r') as json_file:
    data = json.load(json_file)

# %%
plotErrorToAdaptIterations(data)

# %%
plotErrorToAdaptAndOptimizerIterations(data)

# %%
plotErrorToCumulativeShots(data)
# Out:
# [1.0e+07 1.0e+08 1.8e+08 2.8e+08 4.0e+08]

# %%
import json
from visualization.visualize import plotErrorToAdaptIterations, plotErrorToAdaptAndOptimizerIterations, plotErrorToCumulativeShots

filename = '../data/data_H2_N=100_k=10_Nexp=2_T=080125_134030.json'

with open(filename, 'r') as json_file:
    data_h2 = json.load(json_file)

# %%
plotErrorToAdaptIterations(data_h2)

# %%
import json
from visualization.visualize import plotErrorToAdaptIterations, plotErrorToAdaptAndOptimizerIterations, plotErrorToCumulativeShots

filename = '../data/data_H2_N=10000000_k=1000_Nexp=50_T=100125_200635.json'

with open(filename, 'r') as json_file:
    data_h2_50 = json.load(json_file)

# %%
plotErrorToCumulativeShots(data_h2)
# Out:
# [ 100. 1000.]

# %%
plotErrorToAdaptIterations(data_h2_50)

# %%
plotErrorToAdaptAndOptimizerIterations(data_h2_50)

# %%
plotErrorToCumulativeShots(data_h2_50)
# Out:
# [1.e+07 1.e+08]

# %% [markdown]
# ## LiH

# %%
import json
from visualization.visualize import plotErrorToAdaptIterations, plotErrorToAdaptAndOptimizerIterations, plotErrorToCumulativeShots

filename = '../data/data_LiH_N=1000_k=10_Nexp=5_T=100125_175753.json'

with open(filename, 'r') as json_file:
    data_LiH = json.load(json_file)

# %%
plotErrorToAdaptIterations(data_LiH)

# %%
plotErrorToAdaptAndOptimizerIterations(data_LiH)

# %%
plotErrorToCumulativeShots(data_LiH)
# Out:
# [ 1000. 10000. 18000. 24000. 25000. 54000. 56000. 64000. 54000. 50000.
#  77000.]
