# %%
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append('/home/azhar04/project/1. dev/quantum-dev/ShotOptimized-ADAPT-VQE/')
print(sys.executable)

import json
from visualization.visualize import plotErrorToAdaptIterations, plotErrorToAdaptAndOptimizerIterations, plotErrorToCumulativeShots
# Out:
# /home/azhar04/anaconda3/envs/qiskit-1-2/bin/python

# %% [markdown]
# ## H2 10M FC

# %%
filename = '../data/data_H2_N=10000000_k=1000_Nexp=50_T=150125_152104.json'

with open(filename, 'r') as json_file:
    data_H2_10M_FC = json.load(json_file)

# %%
plotErrorToAdaptIterations(data_H2_10M_FC)

# %%
plotErrorToAdaptAndOptimizerIterations(data_H2_10M_FC)

# %%
plotErrorToCumulativeShots(data_H2_10M_FC)
# Out:
# [1.e+07 1.e+08]

# %%
data_H2_10M_FC
# Out:
# {'pool_name': 'QE',
#  'initial_energy': -1.1166512474115224,
#  'fci_energy': -1.1372633383635353,
#  'data_list': [{'energies_statevector': [-1.1166512474115224],
#    'energies_uniform': [-1.1166512474115224],
#    'energies_vmsa': [-1.1166512474115224],
#    'energies_vpsr': [-1.1166512474115224],
#    'std_uniform': [0.0],
#    'std_vmsa': [0.0],
#    'std_vpsr': [0.0],
#    'shots_uniform': [[5000000, 5000000]],
#    'shots_vmsa': [[9998000, 1]],
#    'shots_vpsr': [[4999000, 1]]},
#   {'energies_statevector': [-1.1166512474115216,
#     -1.1166512437850733,
#     -0.16669246730467863,
#     -0.16669248313035734,
#     -1.1367682481403338,
#     -1.1367682475747674,
#     -1.1372632894913415,
#     -1.1372632894969612,
#     -1.137263338363534,
#     -1.1372633383635333],
#    'energies_uniform': [-1.1166512474115224,
#     -1.1166512474115224,
#     -0.0018274512285205646,
#     -0.0017907158782819587,
#     -1.1022866044511979,
#     -1.10226779277776,
# ...

# %% [markdown]
# ## H2 10M QWC

# %%
filename = '../data/data_H2_N=10000000_k=1000_Nexp=50_T=100125_200635.json'

with open(filename, 'r') as json_file:
    data_H2_10M_QWC = json.load(json_file)

# %%
plotErrorToAdaptIterations(data_H2_10M_QWC)

# %%
plotErrorToAdaptAndOptimizerIterations(data_H2_10M_QWC)

# %%
plotErrorToCumulativeShots(data_H2_10M_QWC)
# Out:
# [1.e+07 1.e+08]

# %%
data_H2_10M_QWC
# Out:
# {'pool_name': 'QE',
#  'initial_energy': -1.1166512474115224,
#  'fci_energy': -1.1372633383635353,
#  'data_list': [{'energies_statevector': [-1.1166512474115224],
#    'energies_uniform': [-1.1166562374041238],
#    'energies_vmsa': [-1.1166438296438377],
#    'energies_vpsr': [-1.1166540313432227],
#    'std_uniform': [7.480084542256557e-05],
#    'std_vmsa': [6.659429166310908e-05],
#    'std_vpsr': [6.401508735573402e-05],
#    'shots_uniform': [[2000000, 2000000, 2000000, 2000000, 2000000]],
#    'shots_vmsa': [[2500289, 2497822, 2500344, 2496545, 1]],
#    'shots_vpsr': [[1998882, 1998466, 1999302, 1999350, 1]]},
#   {'energies_statevector': [-1.1166512474115216,
#     -1.1166512437850733,
#     -0.16669246730467863,
#     -0.16669248313035734,
#     -1.1367682481403338,
#     -1.1367682475747674,
#     -1.1372632894913415,
#     -1.1372632894969612,
#     -1.137263338363534,
#     -1.1372633383635333],
#    'energies_uniform': [-1.1166461613180465,
#     -1.116640572961507,
# ...

# %%
filename = '../data/data_H2_N=10000000_k=1000_Nexp=10_070125_140900.json'

with open(filename, 'r') as json_file:
    data_H2_10M_QWC_Nexp10 = json.load(json_file)

# %%
plotErrorToAdaptAndOptimizerIterations(data_H2_10M_QWC_Nexp10)

# %%
data_H2_10M_QWC_Nexp10
# Out:
# {'pool_name': 'QE',
#  'initial_energy': -1.1166512474115224,
#  'fci_energy': -1.1372633383635353,
#  'data_list': [{'energies_statevector': [-1.1166512474115224],
#    'energies_uniform': [-1.1166562374041238],
#    'energies_vmsa': [-1.1166438296438377],
#    'energies_vpsr': [-1.1166540313432227],
#    'std_uniform': [7.480084542256557e-05],
#    'std_vmsa': [6.659429166310908e-05],
#    'std_vpsr': [6.401508735573402e-05],
#    'shots_uniform': [[2000000, 2000000, 2000000, 2000000, 2000000]],
#    'shots_vmsa': [[2500289, 2497822, 2500344, 2496545, 1]],
#    'shots_vpsr': [[1998882, 1998466, 1999302, 1999350, 1]]},
#   {'energies_statevector': [-1.1166512474115216,
#     -1.1166512437850733,
#     -0.16669246730467863,
#     -0.16669248313035734,
#     -1.1367682481403338,
#     -1.1367682475747674,
#     -1.1372632894913415,
#     -1.1372632894969612,
#     -1.137263338363534,
#     -1.1372633383635333],
#    'energies_uniform': [-1.1166461613180465,
#     -1.116640572961507,
# ...

# %%
filename = '../data/data_H2_N=10000000_k=1000_Nexp=50_T=160125_060456.json'

with open(filename, 'r') as json_file:
    data_H2_10M_QWC_v2 = json.load(json_file)

# %%
plotErrorToAdaptAndOptimizerIterations(data_H2_10M_QWC_v2)

# %%
plotErrorToAdaptIterations(data_H2_10M_QWC_v2)

# %%
plotErrorToCumulativeShots(data_H2_10M_QWC_v2)
# Out:
# [1.e+07 1.e+08]
